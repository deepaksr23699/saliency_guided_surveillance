# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %% [markdown]
# # ---------------------- Imports ----------------------

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
from torchsummary import summary 
import onnx 
import onnxruntime as ort
from sklearn.metrics import precision_score, recall_score, f1_score
import random
import os
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # ---------------------- Dataset Class ----------------------

# %%
class SaliencyDataset(Dataset):
    def __init__(self, image_paths, mask_paths, transform=None):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert("L")
        mask = Image.open(self.mask_paths[idx]).convert("L")

        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)

        return image, mask

# %% [markdown]
# # ---------------------- Paths & Setup ----------------------

# %%
# List of folders
image_dirs = [
    r"/home/deepaksr/project/Saliency_datasets/IR_only/Actual scenario/images",
    r"/home/deepaksr/project/Saliency_datasets/IR_only/Bridge data/images",
    r"/home/deepaksr/project/Saliency_datasets/IR_only/hit-uav/images/test",
    r"/home/deepaksr/project/Saliency_datasets/IR_only/hit-uav/images/train",
    r"/home/deepaksr/project/Saliency_datasets/IR_only/hit-uav/images/val",
    r"/home/deepaksr/project/Saliency_datasets/co-reg/simulated/images/RGB",
    r"/home/deepaksr/project/Saliency_datasets/co-reg/paper_dataset/images/RGB"
]

mask_dirs = [
    r"/home/deepaksr/project/Saliency_datasets/IR_only/Actual scenario/saliency_masks",
    r"/home/deepaksr/project/Saliency_datasets/IR_only/Bridge data/saliency_masks",
    r"/home/deepaksr/project/Saliency_datasets/IR_only/hit-uav/saliency_masks/test",
    r"/home/deepaksr/project/Saliency_datasets/IR_only/hit-uav/saliency_masks/train",
    r"/home/deepaksr/project/Saliency_datasets/IR_only/hit-uav/saliency_masks/val",
    r"/home/deepaksr/project/Saliency_datasets/co-reg/simulated/saliency_masks",
    r"/home/deepaksr/project/Saliency_datasets/co-reg/paper_dataset/Saliency_map/RGB"
]

# Collect all images and masks
image_files = []
mask_files = []

for img_dir, msk_dir in zip(image_dirs, mask_dirs):
    imgs = sorted([os.path.join(img_dir, f) for f in os.listdir(img_dir) if f.endswith(".jpg") or f.endswith(".png")])
    msks = sorted([os.path.join(msk_dir, f) for f in os.listdir(msk_dir) if f.endswith(".jpg") or f.endswith(".png")])

    assert len(imgs) == len(msks), f"Mismatch in number of images and masks in {img_dir}"

    image_files.extend(imgs)
    mask_files.extend(msks)

# Split into training and test sets
# First split: 80% train, 20% temp (to be split into val/test)
train_imgs, temp_imgs, train_masks, temp_masks = train_test_split(
    image_files, mask_files, test_size=0.2, random_state=42
)

# Second split: 10% val, 10% test (i.e., split temp in half)
val_imgs, test_imgs, val_masks, test_masks = train_test_split(
    temp_imgs, temp_masks, test_size=0.5, random_state=42
)

#train_imgs, test_imgs, train_masks, test_masks = train_test_split(image_files, mask_files, test_size=0.2, random_state=42)

# %% [markdown]
# # ---------------- Datasets and DataLoaders ----------------

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

train_dataset = SaliencyDataset(train_imgs, train_masks, transform=transform)
val_dataset = SaliencyDataset(val_imgs, val_masks, transform=transform)
test_dataset = SaliencyDataset(test_imgs, test_masks, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# # ---------------------- Verify dataset ----------------------

# %%
print(f"Total images: {len(image_files)}")
print(f"Total masks: {len(mask_files)}")
print(f"Training images: {len(train_imgs)}, Training masks: {len(train_masks)}")
print(f"Validation images: {len(val_imgs)}, Validation masks: {len(val_masks)}")
print(f"Testing images: {len(test_imgs)}, Testing masks: {len(test_masks)}")
# Visualize some train images and masks
img, msk = train_dataset[100]
plt.subplot(1,2,1)
plt.imshow(img.squeeze(), cmap='gray')
plt.title('Image')
plt.subplot(1,2,2)
plt.imshow(msk.squeeze(), cmap='gray')
plt.title('Mask')
plt.show()
# Out:
# Total images: 31566
# Total masks: 31566
# Training images: 25252, Training masks: 25252
# Validation images: 3157, Validation masks: 3157
# Testing images: 3157, Testing masks: 3157

# %% [markdown]
# # ---------------------- Defined Model ----------------------

# %%
class Saliency_IR_v2(nn.Module):
    def __init__(self):
        super(Saliency_IR_v2, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(8, 16, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2)
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2), nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=2, stride=2), nn.ReLU(),
            nn.ConvTranspose2d(16, 8, kernel_size=2, stride=2), nn.ReLU(),
            nn.ConvTranspose2d(8, 1, kernel_size=2, stride=2), nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# ## Training Setup

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1.0):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, inputs, targets):
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        intersection = (inputs * targets).sum()
        dice = (2. * intersection + self.smooth) / (inputs.sum() + targets.sum() + self.smooth)
        return 1 - dice

class HybridLoss(nn.Module):
    def __init__(self, alpha=0.5):
        super(HybridLoss, self).__init__()
        self.alpha = alpha
        self.bce = nn.BCELoss()
        self.dice = DiceLoss()

    def forward(self, inputs, targets):
        return self.alpha * self.bce(inputs, targets) + (1 - self.alpha) * self.dice(inputs, targets)

# %%
def train_model(model, criterion, optimizer, scheduler=None, num_epochs=25, log_prefix="exp", device="cuda"):
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    log_dir = f"./training_logs/{log_prefix}_{timestamp}"
    os.makedirs(log_dir, exist_ok=True)

    train_losses, val_losses, lrs = [], [], []
    best_val_loss = float('inf')
    best_model_path = os.path.join(log_dir, "best_model.pth")

    for epoch in range(num_epochs):
        model.train()
        total_train_loss = 0.0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # Validation
        model.eval()
        total_val_loss = 0.0
        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)
                loss = criterion(outputs, masks)
                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        # Learning rate tracking
        current_lr = optimizer.param_groups[0]['lr']
        lrs.append(current_lr)

        if scheduler:
            scheduler.step(avg_val_loss)

        print(f"Epoch [{epoch+1}/{num_epochs}] | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), best_model_path)
            print(f"  Saved best model at epoch {epoch+1} (Val Loss: {best_val_loss:.4f})")

    # Plot losses
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title("Loss Curve")
    plt.grid(True)
    plt.savefig(os.path.join(log_dir, "loss_plot.png"))
    plt.show()

    # Optionally save CSV
    with open(os.path.join(log_dir, "loss_log.csv"), "w") as f:
        f.write("epoch,train_loss,val_loss,lr\n")
        for i in range(num_epochs):
            f.write(f"{i+1},{train_losses[i]:.4f},{val_losses[i]:.4f},{lrs[i]:.6f}\n")

    return best_model_path

# %%
def compute_min_pixel_fraction(dataloader, bin_thresh=0.5):
    """
    Compute the minimum non-zero area fraction across all ground-truth masks.
    binarization uses bin_thresh, but this only drives area fraction computation.
    """
    min_frac = float('inf')
    for _, masks in dataloader:
        m_np = masks.numpy()  # shape (B,1,H,W)
        for m in m_np:
            binary = (m[0] >= bin_thresh).astype(np.uint8)
            total = binary.size
            salient = binary.sum()
            if salient > 0:
                min_frac = min(min_frac, salient/total)
    if min_frac == float('inf'):
        raise RuntimeError("No non-empty masks found.")
    return min_frac

def evaluate_model(
    model,
    dataloader,
    device,
    bin_thresh=0.5,
    area_frac=None,
    compute_area_frac=False,
    beta2=0.3,
    save_model_path=None,
    visualize=False
):
    """
    Evaluate a saliency model.

    Args:
      model:          the torch model in eval mode
      dataloader:     DataLoader for GT/test images
      device:         'cuda' or 'cpu'
      bin_thresh:     threshold to binarize saliency maps (default 0.5)
      area_frac:      pixel fraction for object-presence logic
      compute_area_frac: if True, override area_frac by computing from GT masks
      beta2:          beta^2 for weighted F-score
      save_model_path: optional path to save model weights
      visualize:      if True, display one example
    
    Returns:
      dict of metrics + used thresholds
    """
    model.eval()
    if compute_area_frac:
        area_frac = compute_min_pixel_fraction(dataloader, bin_thresh)
        print(f"[INFO] Computed area_frac={area_frac:.6f} from GT masks")

    # Metrics accumulators
    mae_sum = 0
    prec_sum = 0
    rec_sum = 0
    iou_list = []
    y_true, y_pred = [], []
    n = 0

    with torch.no_grad():
        for images, masks in dataloader:
            images, masks = images.to(device), masks.to(device)
            outputs = model(images).cpu().numpy()
            gts = masks.cpu().numpy()

            for pred, gt in zip(outputs, gts):
                pred = pred[0]; gt = gt[0]
                # MAE
                mae_sum += np.mean(np.abs(pred - gt))
                # Binary masks
                pbin = (pred >= bin_thresh).astype(np.uint8)
                gbin = (gt   >= bin_thresh).astype(np.uint8)
                # Precision/Recall
                tp = (pbin & gbin).sum()
                fp = (pbin & (1-gbin)).sum()
                fn = ((1-pbin) & gbin).sum()
                prec = tp / (tp+fp+1e-8)
                rec  = tp / (tp+fn+1e-8)
                prec_sum += prec; rec_sum += rec
                # IoU
                inter = (pbin & gbin).sum()
                union = (pbin | gbin).sum()
                iou_list.append(inter/union if union>0 else float(inter==0))
                # Object-presence
                def has_obj(mask):
                    return (mask.sum() / mask.size) > area_frac
                y_true.append(has_obj(gbin))
                y_pred.append(has_obj(pbin))

                n += 1

    # Final aggregations
    mae      = mae_sum / n
    precision= prec_sum / n
    recall   = rec_sum / n
    fbeta    = (1+beta2)*precision*recall/(beta2*precision+recall+1e-8)
    miou     = np.mean(iou_list)
    tp_obj   = sum(t and p for t,p in zip(y_true,y_pred))
    fn_obj   = sum(t and not p for t,p in zip(y_true,y_pred))
    obj_recl = tp_obj / (tp_obj+fn_obj+1e-6)

    # Print
    print("\n=== Evaluation Results ===")
    print(f"MAE            : {mae:.4f}")
    print(f"Precision      : {precision:.4f}")
    print(f"Recall         : {recall:.4f}")
    print(f"Fβ (β²={beta2}): {fbeta:.4f}")
    print(f"Mean IoU       : {miou:.4f}")
    print(f"Obj Presence R : {obj_recl:.4f}")
    print(f"Binarize thres.: {bin_thresh:.2f}")
    print(f"Area fraction  : {area_frac:.6f}")

    # Optional visualize
    if visualize:
        img, gt_mask = images[0], masks[0][0]
        pred_mask = outputs[0][0]
        fig, axs = plt.subplots(1,3,figsize=(12,4))
        axs[0].imshow(img.permute(1,2,0).cpu());     axs[0].set_title("Image")
        axs[1].imshow(gt_mask.cpu(),cmap='gray');   axs[1].set_title("GT Mask")
        axs[2].imshow(pred_mask,cmap='gray');       axs[2].set_title("Pred Mask")
        plt.show()

    # Optional save model
    if save_model_path:
        torch.save(model.state_dict(), save_model_path)
        print(f"[INFO] Model saved to {save_model_path}")

    return {
        "mae":mae, "precision":precision, "recall":recall,
        "f_beta":fbeta, "miou":miou, "obj_recall":obj_recl,
        "bin_thresh":bin_thresh, "area_frac":area_frac
    }

# %% [markdown]
# ### Training

# %%
# 1. Fixed LR, BCE
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Saliency_IR_v2().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.BCELoss()
train_model(model, criterion, optimizer, log_prefix="fixed_bce")
# Out:
# Epoch [1/25] | LR: 0.001000 | Train Loss: 0.1643 | Val Loss: 0.1270
#   Saved best model at epoch 1 (Val Loss: 0.1270)
# Epoch [2/25] | LR: 0.001000 | Train Loss: 0.1283 | Val Loss: 0.1213
#   Saved best model at epoch 2 (Val Loss: 0.1213)
# Epoch [3/25] | LR: 0.001000 | Train Loss: 0.1228 | Val Loss: 0.1108
#   Saved best model at epoch 3 (Val Loss: 0.1108)
# Epoch [4/25] | LR: 0.001000 | Train Loss: 0.1040 | Val Loss: 0.0923
#   Saved best model at epoch 4 (Val Loss: 0.0923)
# Epoch [5/25] | LR: 0.001000 | Train Loss: 0.0959 | Val Loss: 0.0905
#   Saved best model at epoch 5 (Val Loss: 0.0905)
# Epoch [6/25] | LR: 0.001000 | Train Loss: 0.0908 | Val Loss: 0.0833
#   Saved best model at epoch 6 (Val Loss: 0.0833)
# Epoch [7/25] | LR: 0.001000 | Train Loss: 0.0860 | Val Loss: 0.0781
#   Saved best model at epoch 7 (Val Loss: 0.0781)
# Epoch [8/25] | LR: 0.001000 | Train Loss: 0.0828 | Val Loss: 0.0771
#   Saved best model at epoch 8 (Val Loss: 0.0771)
# Epoch [9/25] | LR: 0.001000 | Train Loss: 0.0795 | Val Loss: 0.0712
#   Saved best model at epoch 9 (Val Loss: 0.0712)
# Epoch [10/25] | LR: 0.001000 | Train Loss: 0.0761 | Val Loss: 0.0690
#   Saved best model at epoch 10 (Val Loss: 0.0690)
# Epoch [11/25] | LR: 0.001000 | Train Loss: 0.0733 | Val Loss: 0.0659
#   Saved best model at epoch 11 (Val Loss: 0.0659)
# Epoch [12/25] | LR: 0.001000 | Train Loss: 0.0713 | Val Loss: 0.0676
# Epoch [13/25] | LR: 0.001000 | Train Loss: 0.0694 | Val Loss: 0.0666
# Epoch [14/25] | LR: 0.001000 | Train Loss: 0.0672 | Val Loss: 0.0622
#   Saved best model at epoch 14 (Val Loss: 0.0622)
# Epoch [15/25] | LR: 0.001000 | Train Loss: 0.0657 | Val Loss: 0.0637
# Epoch [16/25] | LR: 0.001000 | Train Loss: 0.0645 | Val Loss: 0.0607
#   Saved best model at epoch 16 (Val Loss: 0.0607)
# Epoch [17/25] | LR: 0.001000 | Train Loss: 0.0629 | Val Loss: 0.0577
#   Saved best model at epoch 17 (Val Loss: 0.0577)
# Epoch [18/25] | LR: 0.001000 | Train Loss: 0.0619 | Val Loss: 0.0566
#   Saved best model at epoch 18 (Val Loss: 0.0566)
# Epoch [19/25] | LR: 0.001000 | Train Loss: 0.0607 | Val Loss: 0.0557
#   Saved best model at epoch 19 (Val Loss: 0.0557)
# Epoch [20/25] | LR: 0.001000 | Train Loss: 0.0603 | Val Loss: 0.0577
# Epoch [21/25] | LR: 0.001000 | Train Loss: 0.0594 | Val Loss: 0.0541
#   Saved best model at epoch 21 (Val Loss: 0.0541)
# Epoch [22/25] | LR: 0.001000 | Train Loss: 0.0587 | Val Loss: 0.0540
#   Saved best model at epoch 22 (Val Loss: 0.0540)
# Epoch [23/25] | LR: 0.001000 | Train Loss: 0.0582 | Val Loss: 0.0559
# Epoch [24/25] | LR: 0.001000 | Train Loss: 0.0573 | Val Loss: 0.0546
# Epoch [25/25] | LR: 0.001000 | Train Loss: 0.0565 | Val Loss: 0.0524
#   Saved best model at epoch 25 (Val Loss: 0.0524)
# './training_logs/fixed_bce_20250508_123122/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000305 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0296
# Precision      : 0.6383
# Recall         : 0.5304
# Fβ (β²=0.3): 0.6097
# Mean IoU       : 0.5040
# Obj Presence R : 0.9289
# Binarize thres.: 0.50
# Area fraction  : 0.000305
# === Evaluation Results ===
# MAE            : 0.0296
# Precision      : 0.5739
# Recall         : 0.6223
# Fβ (β²=0.3): 0.5844
# Mean IoU       : 0.4979
# Obj Presence R : 0.9659
# Binarize thres.: 0.30
# Area fraction  : 0.001000

# %%
# 2. Decaying LR, BCE
model = Saliency_IR_v2().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5, verbose=True)
criterion = nn.BCELoss()
train_model(model, criterion, optimizer, scheduler, log_prefix="decay_bce")
# Out:
# /home/deepaksr/miniconda3/envs/cnn/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/25] | LR: 0.001000 | Train Loss: 0.2222 | Val Loss: 0.1244
#   Saved best model at epoch 1 (Val Loss: 0.1244)
# Epoch [2/25] | LR: 0.001000 | Train Loss: 0.1278 | Val Loss: 0.1223
#   Saved best model at epoch 2 (Val Loss: 0.1223)
# Epoch [3/25] | LR: 0.001000 | Train Loss: 0.1249 | Val Loss: 0.1139
#   Saved best model at epoch 3 (Val Loss: 0.1139)
# Epoch [4/25] | LR: 0.001000 | Train Loss: 0.1081 | Val Loss: 0.0934
#   Saved best model at epoch 4 (Val Loss: 0.0934)
# Epoch [5/25] | LR: 0.001000 | Train Loss: 0.0962 | Val Loss: 0.0884
#   Saved best model at epoch 5 (Val Loss: 0.0884)
# Epoch [6/25] | LR: 0.001000 | Train Loss: 0.0919 | Val Loss: 0.0859
#   Saved best model at epoch 6 (Val Loss: 0.0859)
# Epoch [7/25] | LR: 0.001000 | Train Loss: 0.0894 | Val Loss: 0.0824
#   Saved best model at epoch 7 (Val Loss: 0.0824)
# Epoch [8/25] | LR: 0.001000 | Train Loss: 0.0874 | Val Loss: 0.0801
#   Saved best model at epoch 8 (Val Loss: 0.0801)
# Epoch [9/25] | LR: 0.001000 | Train Loss: 0.0844 | Val Loss: 0.0771
#   Saved best model at epoch 9 (Val Loss: 0.0771)
# Epoch [10/25] | LR: 0.001000 | Train Loss: 0.0822 | Val Loss: 0.0775
# Epoch [11/25] | LR: 0.001000 | Train Loss: 0.0804 | Val Loss: 0.0735
#   Saved best model at epoch 11 (Val Loss: 0.0735)
# Epoch [12/25] | LR: 0.001000 | Train Loss: 0.0776 | Val Loss: 0.0701
#   Saved best model at epoch 12 (Val Loss: 0.0701)
# Epoch [13/25] | LR: 0.001000 | Train Loss: 0.0755 | Val Loss: 0.0685
#   Saved best model at epoch 13 (Val Loss: 0.0685)
# Epoch [14/25] | LR: 0.001000 | Train Loss: 0.0738 | Val Loss: 0.0700
# Epoch [15/25] | LR: 0.001000 | Train Loss: 0.0720 | Val Loss: 0.0658
#   Saved best model at epoch 15 (Val Loss: 0.0658)
# Epoch [16/25] | LR: 0.001000 | Train Loss: 0.0702 | Val Loss: 0.0653
#   Saved best model at epoch 16 (Val Loss: 0.0653)
# Epoch [17/25] | LR: 0.001000 | Train Loss: 0.0692 | Val Loss: 0.0623
#   Saved best model at epoch 17 (Val Loss: 0.0623)
# Epoch [18/25] | LR: 0.001000 | Train Loss: 0.0684 | Val Loss: 0.0622
#   Saved best model at epoch 18 (Val Loss: 0.0622)
# Epoch [19/25] | LR: 0.001000 | Train Loss: 0.0668 | Val Loss: 0.0616
#   Saved best model at epoch 19 (Val Loss: 0.0616)
# Epoch [20/25] | LR: 0.001000 | Train Loss: 0.0655 | Val Loss: 0.0612
#   Saved best model at epoch 20 (Val Loss: 0.0612)
# Epoch [21/25] | LR: 0.001000 | Train Loss: 0.0647 | Val Loss: 0.0586
#   Saved best model at epoch 21 (Val Loss: 0.0586)
# Epoch [22/25] | LR: 0.001000 | Train Loss: 0.0634 | Val Loss: 0.0595
# Epoch [23/25] | LR: 0.001000 | Train Loss: 0.0625 | Val Loss: 0.0604
# Epoch [24/25] | LR: 0.001000 | Train Loss: 0.0621 | Val Loss: 0.0575
#   Saved best model at epoch 24 (Val Loss: 0.0575)
# Epoch [25/25] | LR: 0.001000 | Train Loss: 0.0609 | Val Loss: 0.0562
#   Saved best model at epoch 25 (Val Loss: 0.0562)
# './training_logs/decay_bce_20250508_152639/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000305 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0277
# Precision      : 0.6386
# Recall         : 0.4345
# Fβ (β²=0.3): 0.5761
# Mean IoU       : 0.4560
# Obj Presence R : 0.8601
# Binarize thres.: 0.50
# Area fraction  : 0.000305
# === Evaluation Results ===
# MAE            : 0.0277
# Precision      : 0.6077
# Recall         : 0.5234
# Fβ (β²=0.3): 0.5859
# Mean IoU       : 0.4813
# Obj Presence R : 0.9082
# Binarize thres.: 0.30
# Area fraction  : 0.001000

# %%
# 3. Fixed LR, Dice
model = Saliency_IR_v2().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = DiceLoss()
train_model(model, criterion, optimizer, log_prefix="fixed_dice")
# Out:
# Epoch [1/25] | LR: 0.001000 | Train Loss: 0.7999 | Val Loss: 0.6258
#   Saved best model at epoch 1 (Val Loss: 0.6258)
# Epoch [2/25] | LR: 0.001000 | Train Loss: 0.6089 | Val Loss: 0.5502
#   Saved best model at epoch 2 (Val Loss: 0.5502)
# Epoch [3/25] | LR: 0.001000 | Train Loss: 0.5744 | Val Loss: 0.5326
#   Saved best model at epoch 3 (Val Loss: 0.5326)
# Epoch [4/25] | LR: 0.001000 | Train Loss: 0.5537 | Val Loss: 0.6157
# Epoch [5/25] | LR: 0.001000 | Train Loss: 0.5431 | Val Loss: 0.5196
#   Saved best model at epoch 5 (Val Loss: 0.5196)
# Epoch [6/25] | LR: 0.001000 | Train Loss: 0.5347 | Val Loss: 0.5399
# Epoch [7/25] | LR: 0.001000 | Train Loss: 0.5222 | Val Loss: 0.4885
#   Saved best model at epoch 7 (Val Loss: 0.4885)
# Epoch [8/25] | LR: 0.001000 | Train Loss: 0.5162 | Val Loss: 0.4797
#   Saved best model at epoch 8 (Val Loss: 0.4797)
# Epoch [9/25] | LR: 0.001000 | Train Loss: 0.5068 | Val Loss: 0.4714
#   Saved best model at epoch 9 (Val Loss: 0.4714)
# Epoch [10/25] | LR: 0.001000 | Train Loss: 0.4967 | Val Loss: 0.4770
# Epoch [11/25] | LR: 0.001000 | Train Loss: 0.4887 | Val Loss: 0.4571
#   Saved best model at epoch 11 (Val Loss: 0.4571)
# Epoch [12/25] | LR: 0.001000 | Train Loss: 0.4782 | Val Loss: 0.4517
#   Saved best model at epoch 12 (Val Loss: 0.4517)
# Epoch [13/25] | LR: 0.001000 | Train Loss: 0.4746 | Val Loss: 0.4406
#   Saved best model at epoch 13 (Val Loss: 0.4406)
# Epoch [14/25] | LR: 0.001000 | Train Loss: 0.4679 | Val Loss: 0.4352
#   Saved best model at epoch 14 (Val Loss: 0.4352)
# Epoch [15/25] | LR: 0.001000 | Train Loss: 0.4614 | Val Loss: 0.4322
#   Saved best model at epoch 15 (Val Loss: 0.4322)
# Epoch [16/25] | LR: 0.001000 | Train Loss: 0.4561 | Val Loss: 0.4277
#   Saved best model at epoch 16 (Val Loss: 0.4277)
# Epoch [17/25] | LR: 0.001000 | Train Loss: 0.4518 | Val Loss: 0.4283
# Epoch [18/25] | LR: 0.001000 | Train Loss: 0.4465 | Val Loss: 0.4426
# Epoch [19/25] | LR: 0.001000 | Train Loss: 0.4411 | Val Loss: 0.4124
#   Saved best model at epoch 19 (Val Loss: 0.4124)
# Epoch [20/25] | LR: 0.001000 | Train Loss: 0.4358 | Val Loss: 0.4158
# Epoch [21/25] | LR: 0.001000 | Train Loss: 0.4308 | Val Loss: 0.4019
#   Saved best model at epoch 21 (Val Loss: 0.4019)
# Epoch [22/25] | LR: 0.001000 | Train Loss: 0.4278 | Val Loss: 0.4065
# Epoch [23/25] | LR: 0.001000 | Train Loss: 0.4244 | Val Loss: 0.3985
#   Saved best model at epoch 23 (Val Loss: 0.3985)
# Epoch [24/25] | LR: 0.001000 | Train Loss: 0.4202 | Val Loss: 0.3952
#   Saved best model at epoch 24 (Val Loss: 0.3952)
# Epoch [25/25] | LR: 0.001000 | Train Loss: 0.4188 | Val Loss: 0.3901
#   Saved best model at epoch 25 (Val Loss: 0.3901)
# './training_logs/fixed_dice_20250508_182157/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000305 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0197
# Precision      : 0.5591
# Recall         : 0.5456
# Fβ (β²=0.3): 0.5559
# Mean IoU       : 0.4939
# Obj Presence R : 0.8203
# Binarize thres.: 0.50
# Area fraction  : 0.000305
# === Evaluation Results ===
# MAE            : 0.0197
# Precision      : 0.5680
# Recall         : 0.5431
# Fβ (β²=0.3): 0.5621
# Mean IoU       : 0.4951
# Obj Presence R : 0.8010
# Binarize thres.: 0.30
# Area fraction  : 0.001000

# %%
# 4. Decaying LR, Dice
model = Saliency_IR_v2().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5, verbose=True)
criterion = DiceLoss()
train_model(model, criterion, optimizer, scheduler, log_prefix="decay_dice")
# Out:
# Epoch [1/25] | LR: 0.001000 | Train Loss: 0.9269 | Val Loss: 0.8533
#   Saved best model at epoch 1 (Val Loss: 0.8533)
# Epoch [2/25] | LR: 0.001000 | Train Loss: 0.6234 | Val Loss: 0.5499
#   Saved best model at epoch 2 (Val Loss: 0.5499)
# Epoch [3/25] | LR: 0.001000 | Train Loss: 0.5414 | Val Loss: 0.4979
#   Saved best model at epoch 3 (Val Loss: 0.4979)
# Epoch [4/25] | LR: 0.001000 | Train Loss: 0.5128 | Val Loss: 0.4887
#   Saved best model at epoch 4 (Val Loss: 0.4887)
# Epoch [5/25] | LR: 0.001000 | Train Loss: 0.4962 | Val Loss: 0.4619
#   Saved best model at epoch 5 (Val Loss: 0.4619)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 6
#       4 scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5, verbose=True)
#       5 criterion = DiceLoss()
# ----> 6 train_model(model, criterion, optimizer, scheduler, log_prefix="decay_dice")
#
# Cell In[9], line 14, in train_model(model, criterion, optimizer, scheduler, num_epochs, log_prefix, device)
#      11 model.train()
#      12 total_train_loss = 0.0
# ---> 14 for images, masks in train_loader:
#      15     images, masks = images.to(device), masks.to(device)
#      16     optimizer.zero_grad()
#
# File ~/miniconda3/envs/cnn/lib/python3.12/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/miniconda3/envs/cnn/lib/python3.12/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/cnn/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[3], line 16, in SaliencyDataset.__getitem__(self, idx)
#      14 if self.transform:
#      15     image = self.transform(image)
# ---> 16     mask = self.transform(mask)
#      18 return image, mask
#
# File ~/miniconda3/envs/cnn/lib/python3.12/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~/miniconda3/envs/cnn/lib/python3.12/site-packages/torchvision/transforms/transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File ~/miniconda3/envs/cnn/lib/python3.12/site-packages/torchvision/transforms/functional.py:176, in to_tensor(pic)
#     174 img = img.permute((2, 0, 1)).contiguous()
#     175 if isinstance(img, torch.ByteTensor):
# --> 176     return img.to(dtype=default_float_dtype).div(255)
#     177 else:
#     178     return img
#
# KeyboardInterrupt:

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)

# %%
# 5. Fixed LR, Hybrid Loss (alpha=0.7)
model = Saliency_IR_v2().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = HybridLoss(alpha=0.7)
train_model(model, criterion, optimizer, log_prefix="fixed_hybrid")

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)

# %%
# 6. Decaying LR, Hybrid Loss (alpha=0.7)
model = Saliency_IR_v2().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5, verbose=True)
criterion = HybridLoss(alpha=0.7)
train_model(model, criterion, optimizer, scheduler, log_prefix="decay_hybrid")

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# # ---------------------- Imports ----------------------

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
from torchsummary import summary 
import onnx 
import onnxruntime as ort
from sklearn.metrics import precision_score, recall_score, f1_score
import random
import os
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # ---------------------- Dataset Class ----------------------

# %%
class SaliencyDataset(Dataset):
    def __init__(self, image_paths, mask_paths, transform=None):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert("RGB")
        mask = Image.open(self.mask_paths[idx]).convert("L")

        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)

        return image, mask

# %% [markdown]
# # ---------------------- Paths & Setup ----------------------

# %%
# List of folders
image_dirs = [
    r"/home/deepaksr/project/Saliency_datasets/co-reg/simulated/images/RGB",
    r"/home/deepaksr/project/Saliency_datasets/co-reg/paper_dataset/images/RGB"
]

mask_dirs = [
    r"/home/deepaksr/project/Saliency_datasets/co-reg/simulated/saliency_masks",
    r"/home/deepaksr/project/Saliency_datasets/co-reg/paper_dataset/Saliency_map/RGB"
]

# Collect all images and masks
image_files = []
mask_files = []

for img_dir, msk_dir in zip(image_dirs, mask_dirs):
    imgs = sorted([os.path.join(img_dir, f) for f in os.listdir(img_dir) if f.endswith(".jpg") or f.endswith(".png")])
    msks = sorted([os.path.join(msk_dir, f) for f in os.listdir(msk_dir) if f.endswith(".jpg") or f.endswith(".png")])

    assert len(imgs) == len(msks), f"Mismatch in number of images and masks in {img_dir}"

    image_files.extend(imgs)
    mask_files.extend(msks)

# Split into training and test sets
# First split: 80% train, 20% temp (to be split into val/test)
train_imgs, temp_imgs, train_masks, temp_masks = train_test_split(
    image_files, mask_files, test_size=0.2, random_state=42
)

# Second split: 10% val, 10% test (i.e., split temp in half)
val_imgs, test_imgs, val_masks, test_masks = train_test_split(
    temp_imgs, temp_masks, test_size=0.5, random_state=42
)

#train_imgs, test_imgs, train_masks, test_masks = train_test_split(image_files, mask_files, test_size=0.2, random_state=42)

# %% [markdown]
# # ---------------- Datasets and DataLoaders ----------------

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

train_dataset = SaliencyDataset(train_imgs, train_masks, transform=transform)
val_dataset = SaliencyDataset(val_imgs, val_masks, transform=transform)
test_dataset = SaliencyDataset(test_imgs, test_masks, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# # ---------------------- Verify dataset ----------------------

# %%
print(f"Total images: {len(image_files)}")
print(f"Total masks: {len(mask_files)}")
print(f"Training images: {len(train_imgs)}, Training masks: {len(train_masks)}")
print(f"Validation images: {len(val_imgs)}, Validation masks: {len(val_masks)}")
print(f"Testing images: {len(test_imgs)}, Testing masks: {len(test_masks)}")
# Visualize some train images and masks
img, msk = train_dataset[2131]
plt.subplot(1,2,1)
plt.imshow(img.permute(1,2,0))
plt.title('Image')
plt.subplot(1,2,2)
plt.imshow(msk.squeeze(), cmap='gray')
plt.title('Mask')
plt.show()
# Out:
# Total images: 4851
# Total masks: 4851
# Training images: 3880, Training masks: 3880
# Validation images: 485, Validation masks: 485
# Testing images: 486, Testing masks: 486

# %% [markdown]
# # ---------------------- Defined Model ----------------------

# %%
class Saliency_RGB_v1(nn.Module):
    def __init__(self):
        super(Saliency_RGB_v1, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1), nn.ReLU(), nn.MaxPool2d(2)
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2), nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2), nn.ReLU(),
            nn.ConvTranspose2d(64, 1, kernel_size=2, stride=2), nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# ## Training Setup

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1.0):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, inputs, targets):
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        intersection = (inputs * targets).sum()
        dice = (2. * intersection + self.smooth) / (inputs.sum() + targets.sum() + self.smooth)
        return 1 - dice

class HybridLoss(nn.Module):
    def __init__(self, alpha=0.5):
        super(HybridLoss, self).__init__()
        self.alpha = alpha
        self.bce = nn.BCELoss()
        self.dice = DiceLoss()

    def forward(self, inputs, targets):
        return self.alpha * self.bce(inputs, targets) + (1 - self.alpha) * self.dice(inputs, targets)

# %%
def train_model(model, criterion, optimizer, scheduler=None, num_epochs=50, log_prefix="exp", device="cuda"):
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    log_dir = f"./training_logs/{log_prefix}_{timestamp}"
    os.makedirs(log_dir, exist_ok=True)

    train_losses, val_losses, lrs = [], [], []
    best_val_loss = float('inf')
    best_model_path = os.path.join(log_dir, "best_model.pth")

    for epoch in range(num_epochs):
        model.train()
        total_train_loss = 0.0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # Validation
        model.eval()
        total_val_loss = 0.0
        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)
                loss = criterion(outputs, masks)
                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        # Learning rate tracking
        current_lr = optimizer.param_groups[0]['lr']
        lrs.append(current_lr)

        if scheduler:
            scheduler.step(avg_val_loss)

        print(f"Epoch [{epoch+1}/{num_epochs}] | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), best_model_path)
            print(f"  Saved best model at epoch {epoch+1} (Val Loss: {best_val_loss:.4f})")

    # Plot losses
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title("Loss Curve")
    plt.grid(True)
    plt.savefig(os.path.join(log_dir, "loss_plot.png"))
    plt.show()

    # Optionally save CSV
    with open(os.path.join(log_dir, "loss_log.csv"), "w") as f:
        f.write("epoch,train_loss,val_loss,lr\n")
        for i in range(num_epochs):
            f.write(f"{i+1},{train_losses[i]:.4f},{val_losses[i]:.4f},{lrs[i]:.6f}\n")

    return best_model_path

# %%
def compute_min_pixel_fraction(dataloader, bin_thresh=0.5):
    """
    Compute the minimum non-zero area fraction across all ground-truth masks.
    binarization uses bin_thresh, but this only drives area fraction computation.
    """
    min_frac = float('inf')
    for _, masks in dataloader:
        m_np = masks.numpy()  # shape (B,1,H,W)
        for m in m_np:
            binary = (m[0] >= bin_thresh).astype(np.uint8)
            total = binary.size
            salient = binary.sum()
            if salient > 0:
                min_frac = min(min_frac, salient/total)
    if min_frac == float('inf'):
        raise RuntimeError("No non-empty masks found.")
    return min_frac

def evaluate_model(
    model,
    dataloader,
    device,
    bin_thresh=0.5,
    area_frac=None,
    compute_area_frac=False,
    beta2=0.3,
    save_model_path=None,
    visualize=False
):
    """
    Evaluate a saliency model.

    Args:
      model:          the torch model in eval mode
      dataloader:     DataLoader for GT/test images
      device:         'cuda' or 'cpu'
      bin_thresh:     threshold to binarize saliency maps (default 0.5)
      area_frac:      pixel fraction for object-presence logic
      compute_area_frac: if True, override area_frac by computing from GT masks
      beta2:          beta^2 for weighted F-score
      save_model_path: optional path to save model weights
      visualize:      if True, display one example
    
    Returns:
      dict of metrics + used thresholds
    """
    model.eval()
    if compute_area_frac:
        area_frac = compute_min_pixel_fraction(dataloader, bin_thresh)
        print(f"[INFO] Computed area_frac={area_frac:.6f} from GT masks")

    # Metrics accumulators
    mae_sum = 0
    prec_sum = 0
    rec_sum = 0
    iou_list = []
    y_true, y_pred = [], []
    n = 0

    with torch.no_grad():
        for images, masks in dataloader:
            images, masks = images.to(device), masks.to(device)
            outputs = model(images).cpu().numpy()
            gts = masks.cpu().numpy()

            for pred, gt in zip(outputs, gts):
                pred = pred[0]; gt = gt[0]
                # MAE
                mae_sum += np.mean(np.abs(pred - gt))
                # Binary masks
                pbin = (pred >= bin_thresh).astype(np.uint8)
                gbin = (gt   >= bin_thresh).astype(np.uint8)
                # Precision/Recall
                tp = (pbin & gbin).sum()
                fp = (pbin & (1-gbin)).sum()
                fn = ((1-pbin) & gbin).sum()
                prec = tp / (tp+fp+1e-8)
                rec  = tp / (tp+fn+1e-8)
                prec_sum += prec; rec_sum += rec
                # IoU
                inter = (pbin & gbin).sum()
                union = (pbin | gbin).sum()
                iou_list.append(inter/union if union>0 else float(inter==0))
                # Object-presence
                def has_obj(mask):
                    return (mask.sum() / mask.size) > area_frac
                y_true.append(has_obj(gbin))
                y_pred.append(has_obj(pbin))

                n += 1

    # Final aggregations
    mae      = mae_sum / n
    precision= prec_sum / n
    recall   = rec_sum / n
    fbeta    = (1+beta2)*precision*recall/(beta2*precision+recall+1e-8)
    miou     = np.mean(iou_list)
    tp_obj   = sum(t and p for t,p in zip(y_true,y_pred))
    fn_obj   = sum(t and not p for t,p in zip(y_true,y_pred))
    obj_recl = tp_obj / (tp_obj+fn_obj+1e-6)

    # Print
    print("\n=== Evaluation Results ===")
    print(f"MAE            : {mae:.4f}")
    print(f"Precision      : {precision:.4f}")
    print(f"Recall         : {recall:.4f}")
    print(f"Fβ (β²={beta2}): {fbeta:.4f}")
    print(f"Mean IoU       : {miou:.4f}")
    print(f"Obj Presence R : {obj_recl:.4f}")
    print(f"Binarize thres.: {bin_thresh:.2f}")
    print(f"Area fraction  : {area_frac:.6f}")

    # Optional visualize
    if visualize:
        img, gt_mask = images[0], masks[0][0]
        pred_mask = outputs[0][0]
        fig, axs = plt.subplots(1,3,figsize=(12,4))
        axs[0].imshow(img.permute(1,2,0).cpu());     axs[0].set_title("Image")
        axs[1].imshow(gt_mask.cpu(),cmap='gray');   axs[1].set_title("GT Mask")
        axs[2].imshow(pred_mask,cmap='gray');       axs[2].set_title("Pred Mask")
        plt.show()

    # Optional save model
    if save_model_path:
        torch.save(model.state_dict(), save_model_path)
        print(f"[INFO] Model saved to {save_model_path}")

    return {
        "mae":mae, "precision":precision, "recall":recall,
        "f_beta":fbeta, "miou":miou, "obj_recall":obj_recl,
        "bin_thresh":bin_thresh, "area_frac":area_frac
    }

# %% [markdown]
# ### Training

# %%
# 1. Fixed LR, BCE
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Saliency_RGB_v1().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.BCELoss()
train_model(model, criterion, optimizer, log_prefix="fixed_bce")
# Out:
# Epoch [1/50] | LR: 0.001000 | Train Loss: 0.2077 | Val Loss: 0.1499
#   Saved best model at epoch 1 (Val Loss: 0.1499)
# Epoch [2/50] | LR: 0.001000 | Train Loss: 0.1522 | Val Loss: 0.1551
# Epoch [3/50] | LR: 0.001000 | Train Loss: 0.1470 | Val Loss: 0.1340
#   Saved best model at epoch 3 (Val Loss: 0.1340)
# Epoch [4/50] | LR: 0.001000 | Train Loss: 0.1375 | Val Loss: 0.1285
#   Saved best model at epoch 4 (Val Loss: 0.1285)
# Epoch [5/50] | LR: 0.001000 | Train Loss: 0.1343 | Val Loss: 0.1233
#   Saved best model at epoch 5 (Val Loss: 0.1233)
# Epoch [6/50] | LR: 0.001000 | Train Loss: 0.1304 | Val Loss: 0.1212
#   Saved best model at epoch 6 (Val Loss: 0.1212)
# Epoch [7/50] | LR: 0.001000 | Train Loss: 0.1246 | Val Loss: 0.1172
#   Saved best model at epoch 7 (Val Loss: 0.1172)
# Epoch [8/50] | LR: 0.001000 | Train Loss: 0.1229 | Val Loss: 0.1216
# Epoch [9/50] | LR: 0.001000 | Train Loss: 0.1199 | Val Loss: 0.1132
#   Saved best model at epoch 9 (Val Loss: 0.1132)
# Epoch [10/50] | LR: 0.001000 | Train Loss: 0.1169 | Val Loss: 0.1053
#   Saved best model at epoch 10 (Val Loss: 0.1053)
# Epoch [11/50] | LR: 0.001000 | Train Loss: 0.1097 | Val Loss: 0.1004
#   Saved best model at epoch 11 (Val Loss: 0.1004)
# Epoch [12/50] | LR: 0.001000 | Train Loss: 0.1055 | Val Loss: 0.0924
#   Saved best model at epoch 12 (Val Loss: 0.0924)
# Epoch [13/50] | LR: 0.001000 | Train Loss: 0.1024 | Val Loss: 0.0953
# Epoch [14/50] | LR: 0.001000 | Train Loss: 0.0982 | Val Loss: 0.0910
#   Saved best model at epoch 14 (Val Loss: 0.0910)
# Epoch [15/50] | LR: 0.001000 | Train Loss: 0.0930 | Val Loss: 0.0848
#   Saved best model at epoch 15 (Val Loss: 0.0848)
# Epoch [16/50] | LR: 0.001000 | Train Loss: 0.0900 | Val Loss: 0.0826
#   Saved best model at epoch 16 (Val Loss: 0.0826)
# Epoch [17/50] | LR: 0.001000 | Train Loss: 0.0881 | Val Loss: 0.0782
#   Saved best model at epoch 17 (Val Loss: 0.0782)
# Epoch [18/50] | LR: 0.001000 | Train Loss: 0.0841 | Val Loss: 0.0790
# Epoch [19/50] | LR: 0.001000 | Train Loss: 0.0819 | Val Loss: 0.0745
#   Saved best model at epoch 19 (Val Loss: 0.0745)
# Epoch [20/50] | LR: 0.001000 | Train Loss: 0.0807 | Val Loss: 0.0748
# Epoch [21/50] | LR: 0.001000 | Train Loss: 0.0775 | Val Loss: 0.0713
#   Saved best model at epoch 21 (Val Loss: 0.0713)
# Epoch [22/50] | LR: 0.001000 | Train Loss: 0.0769 | Val Loss: 0.0695
#   Saved best model at epoch 22 (Val Loss: 0.0695)
# Epoch [23/50] | LR: 0.001000 | Train Loss: 0.0752 | Val Loss: 0.0672
#   Saved best model at epoch 23 (Val Loss: 0.0672)
# Epoch [24/50] | LR: 0.001000 | Train Loss: 0.0728 | Val Loss: 0.0665
#   Saved best model at epoch 24 (Val Loss: 0.0665)
# Epoch [25/50] | LR: 0.001000 | Train Loss: 0.0725 | Val Loss: 0.0689
# Epoch [26/50] | LR: 0.001000 | Train Loss: 0.0720 | Val Loss: 0.0653
#   Saved best model at epoch 26 (Val Loss: 0.0653)
# Epoch [27/50] | LR: 0.001000 | Train Loss: 0.0702 | Val Loss: 0.0661
# Epoch [28/50] | LR: 0.001000 | Train Loss: 0.0702 | Val Loss: 0.0625
#   Saved best model at epoch 28 (Val Loss: 0.0625)
# Epoch [29/50] | LR: 0.001000 | Train Loss: 0.0671 | Val Loss: 0.0638
# Epoch [30/50] | LR: 0.001000 | Train Loss: 0.0672 | Val Loss: 0.0621
#   Saved best model at epoch 30 (Val Loss: 0.0621)
# Epoch [31/50] | LR: 0.001000 | Train Loss: 0.0659 | Val Loss: 0.0641
# Epoch [32/50] | LR: 0.001000 | Train Loss: 0.0670 | Val Loss: 0.0618
#   Saved best model at epoch 32 (Val Loss: 0.0618)
# Epoch [33/50] | LR: 0.001000 | Train Loss: 0.0639 | Val Loss: 0.0634
# Epoch [34/50] | LR: 0.001000 | Train Loss: 0.0632 | Val Loss: 0.0620
# Epoch [35/50] | LR: 0.001000 | Train Loss: 0.0636 | Val Loss: 0.0636
# Epoch [36/50] | LR: 0.001000 | Train Loss: 0.0639 | Val Loss: 0.0591
#   Saved best model at epoch 36 (Val Loss: 0.0591)
# Epoch [37/50] | LR: 0.001000 | Train Loss: 0.0614 | Val Loss: 0.0596
# Epoch [38/50] | LR: 0.001000 | Train Loss: 0.0599 | Val Loss: 0.0587
#   Saved best model at epoch 38 (Val Loss: 0.0587)
# Epoch [39/50] | LR: 0.001000 | Train Loss: 0.0591 | Val Loss: 0.0593
# Epoch [40/50] | LR: 0.001000 | Train Loss: 0.0580 | Val Loss: 0.0589
# Epoch [41/50] | LR: 0.001000 | Train Loss: 0.0590 | Val Loss: 0.0597
# Epoch [42/50] | LR: 0.001000 | Train Loss: 0.0575 | Val Loss: 0.0602
# Epoch [43/50] | LR: 0.001000 | Train Loss: 0.0564 | Val Loss: 0.0576
#   Saved best model at epoch 43 (Val Loss: 0.0576)
# Epoch [44/50] | LR: 0.001000 | Train Loss: 0.0560 | Val Loss: 0.0585
# Epoch [45/50] | LR: 0.001000 | Train Loss: 0.0550 | Val Loss: 0.0570
#   Saved best model at epoch 45 (Val Loss: 0.0570)
# Epoch [46/50] | LR: 0.001000 | Train Loss: 0.0541 | Val Loss: 0.0573
# Epoch [47/50] | LR: 0.001000 | Train Loss: 0.0545 | Val Loss: 0.0584
# Epoch [48/50] | LR: 0.001000 | Train Loss: 0.0536 | Val Loss: 0.0582
# Epoch [49/50] | LR: 0.001000 | Train Loss: 0.0523 | Val Loss: 0.0579
# Epoch [50/50] | LR: 0.001000 | Train Loss: 0.0516 | Val Loss: 0.0631
# './training_logs/fixed_bce_20250508_015625/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000961 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0281
# Precision      : 0.7530
# Recall         : 0.4869
# Fβ (β²=0.3): 0.6687
# Mean IoU       : 0.5043
# Obj Presence R : 0.9407
# Binarize thres.: 0.50
# Area fraction  : 0.000961
# === Evaluation Results ===
# MAE            : 0.0281
# Precision      : 0.7061
# Recall         : 0.5707
# Fβ (β²=0.3): 0.6695
# Mean IoU       : 0.5373
# Obj Presence R : 0.9649
# Binarize thres.: 0.30
# Area fraction  : 0.001000

# %%
# 2. Decaying LR, BCE
model = Saliency_RGB_v1().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5, verbose=True)
criterion = nn.BCELoss()
train_model(model, criterion, optimizer, scheduler, log_prefix="decay_bce")
# Out:
# /home/deepaksr/miniconda3/envs/cnn/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/50] | LR: 0.001000 | Train Loss: 0.1914 | Val Loss: 0.1498
#   Saved best model at epoch 1 (Val Loss: 0.1498)
# Epoch [2/50] | LR: 0.001000 | Train Loss: 0.1543 | Val Loss: 0.1400
#   Saved best model at epoch 2 (Val Loss: 0.1400)
# Epoch [3/50] | LR: 0.001000 | Train Loss: 0.1422 | Val Loss: 0.1393
#   Saved best model at epoch 3 (Val Loss: 0.1393)
# Epoch [4/50] | LR: 0.001000 | Train Loss: 0.1358 | Val Loss: 0.1254
#   Saved best model at epoch 4 (Val Loss: 0.1254)
# Epoch [5/50] | LR: 0.001000 | Train Loss: 0.1309 | Val Loss: 0.1246
#   Saved best model at epoch 5 (Val Loss: 0.1246)
# Epoch [6/50] | LR: 0.001000 | Train Loss: 0.1220 | Val Loss: 0.1148
#   Saved best model at epoch 6 (Val Loss: 0.1148)
# Epoch [7/50] | LR: 0.001000 | Train Loss: 0.1167 | Val Loss: 0.1075
#   Saved best model at epoch 7 (Val Loss: 0.1075)
# Epoch [8/50] | LR: 0.001000 | Train Loss: 0.1117 | Val Loss: 0.0991
#   Saved best model at epoch 8 (Val Loss: 0.0991)
# Epoch [9/50] | LR: 0.001000 | Train Loss: 0.1067 | Val Loss: 0.0924
#   Saved best model at epoch 9 (Val Loss: 0.0924)
# Epoch [10/50] | LR: 0.001000 | Train Loss: 0.1021 | Val Loss: 0.0895
#   Saved best model at epoch 10 (Val Loss: 0.0895)
# Epoch [11/50] | LR: 0.001000 | Train Loss: 0.0971 | Val Loss: 0.0904
# Epoch [12/50] | LR: 0.001000 | Train Loss: 0.0950 | Val Loss: 0.0863
#   Saved best model at epoch 12 (Val Loss: 0.0863)
# Epoch [13/50] | LR: 0.001000 | Train Loss: 0.0921 | Val Loss: 0.0817
#   Saved best model at epoch 13 (Val Loss: 0.0817)
# Epoch [14/50] | LR: 0.001000 | Train Loss: 0.0899 | Val Loss: 0.0832
# Epoch [15/50] | LR: 0.001000 | Train Loss: 0.0862 | Val Loss: 0.0773
#   Saved best model at epoch 15 (Val Loss: 0.0773)
# Epoch [16/50] | LR: 0.001000 | Train Loss: 0.0856 | Val Loss: 0.0762
#   Saved best model at epoch 16 (Val Loss: 0.0762)
# Epoch [17/50] | LR: 0.001000 | Train Loss: 0.0824 | Val Loss: 0.1167
# Epoch [18/50] | LR: 0.001000 | Train Loss: 0.0835 | Val Loss: 0.0759
#   Saved best model at epoch 18 (Val Loss: 0.0759)
# Epoch [19/50] | LR: 0.001000 | Train Loss: 0.0790 | Val Loss: 0.0715
#   Saved best model at epoch 19 (Val Loss: 0.0715)
# Epoch [20/50] | LR: 0.001000 | Train Loss: 0.0776 | Val Loss: 0.0761
# Epoch [21/50] | LR: 0.001000 | Train Loss: 0.0753 | Val Loss: 0.0876
# Epoch [22/50] | LR: 0.001000 | Train Loss: 0.0768 | Val Loss: 0.0678
#   Saved best model at epoch 22 (Val Loss: 0.0678)
# Epoch [23/50] | LR: 0.001000 | Train Loss: 0.0722 | Val Loss: 0.0798
# Epoch [24/50] | LR: 0.001000 | Train Loss: 0.0727 | Val Loss: 0.0664
#   Saved best model at epoch 24 (Val Loss: 0.0664)
# Epoch [25/50] | LR: 0.001000 | Train Loss: 0.0703 | Val Loss: 0.0649
#   Saved best model at epoch 25 (Val Loss: 0.0649)
# Epoch [26/50] | LR: 0.001000 | Train Loss: 0.0708 | Val Loss: 0.0650
# Epoch [27/50] | LR: 0.001000 | Train Loss: 0.0691 | Val Loss: 0.0642
#   Saved best model at epoch 27 (Val Loss: 0.0642)
# Epoch [28/50] | LR: 0.001000 | Train Loss: 0.0672 | Val Loss: 0.0706
# Epoch [29/50] | LR: 0.001000 | Train Loss: 0.0672 | Val Loss: 0.0630
#   Saved best model at epoch 29 (Val Loss: 0.0630)
# Epoch [30/50] | LR: 0.001000 | Train Loss: 0.0664 | Val Loss: 0.0642
# Epoch [31/50] | LR: 0.001000 | Train Loss: 0.0652 | Val Loss: 0.0630
# Epoch [32/50] | LR: 0.001000 | Train Loss: 0.0637 | Val Loss: 0.0611
#   Saved best model at epoch 32 (Val Loss: 0.0611)
# Epoch [33/50] | LR: 0.001000 | Train Loss: 0.0623 | Val Loss: 0.0597
#   Saved best model at epoch 33 (Val Loss: 0.0597)
# Epoch [34/50] | LR: 0.001000 | Train Loss: 0.0630 | Val Loss: 0.0607
# Epoch [35/50] | LR: 0.001000 | Train Loss: 0.0610 | Val Loss: 0.0598
# Epoch [36/50] | LR: 0.001000 | Train Loss: 0.0610 | Val Loss: 0.0605
# Epoch [37/50] | LR: 0.001000 | Train Loss: 0.0602 | Val Loss: 0.0629
# Epoch [38/50] | LR: 0.001000 | Train Loss: 0.0606 | Val Loss: 0.0574
#   Saved best model at epoch 38 (Val Loss: 0.0574)
# Epoch [39/50] | LR: 0.001000 | Train Loss: 0.0577 | Val Loss: 0.0585
# Epoch [40/50] | LR: 0.001000 | Train Loss: 0.0579 | Val Loss: 0.0589
# Epoch [41/50] | LR: 0.001000 | Train Loss: 0.0577 | Val Loss: 0.0601
# Epoch [42/50] | LR: 0.001000 | Train Loss: 0.0564 | Val Loss: 0.0567
#   Saved best model at epoch 42 (Val Loss: 0.0567)
# Epoch [43/50] | LR: 0.001000 | Train Loss: 0.0553 | Val Loss: 0.0578
# Epoch [44/50] | LR: 0.001000 | Train Loss: 0.0565 | Val Loss: 0.0584
# Epoch [45/50] | LR: 0.001000 | Train Loss: 0.0546 | Val Loss: 0.0573
# Epoch [46/50] | LR: 0.001000 | Train Loss: 0.0543 | Val Loss: 0.0602
# Epoch [47/50] | LR: 0.001000 | Train Loss: 0.0558 | Val Loss: 0.0575
# Epoch [48/50] | LR: 0.001000 | Train Loss: 0.0531 | Val Loss: 0.0575
# Epoch [49/50] | LR: 0.000500 | Train Loss: 0.0502 | Val Loss: 0.0555
#   Saved best model at epoch 49 (Val Loss: 0.0555)
# Epoch [50/50] | LR: 0.000500 | Train Loss: 0.0494 | Val Loss: 0.0557
# './training_logs/decay_bce_20250508_032355/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000961 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0285
# Precision      : 0.7145
# Recall         : 0.5908
# Fβ (β²=0.3): 0.6816
# Mean IoU       : 0.5636
# Obj Presence R : 0.9560
# Binarize thres.: 0.50
# Area fraction  : 0.000961
# === Evaluation Results ===
# MAE            : 0.0285
# Precision      : 0.6608
# Recall         : 0.6606
# Fβ (β²=0.3): 0.6608
# Mean IoU       : 0.5621
# Obj Presence R : 0.9715
# Binarize thres.: 0.30
# Area fraction  : 0.001000

# %%
# 3. Fixed LR, Dice
model = Saliency_RGB_v1().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = DiceLoss()
train_model(model, criterion, optimizer, log_prefix="fixed_dice")
# Out:
# Epoch [1/50] | LR: 0.001000 | Train Loss: 0.8427 | Val Loss: 0.7143
#   Saved best model at epoch 1 (Val Loss: 0.7143)
# Epoch [2/50] | LR: 0.001000 | Train Loss: 0.7010 | Val Loss: 0.7009
#   Saved best model at epoch 2 (Val Loss: 0.7009)
# Epoch [3/50] | LR: 0.001000 | Train Loss: 0.6612 | Val Loss: 0.6165
#   Saved best model at epoch 3 (Val Loss: 0.6165)
# Epoch [4/50] | LR: 0.001000 | Train Loss: 0.6333 | Val Loss: 0.6092
#   Saved best model at epoch 4 (Val Loss: 0.6092)
# Epoch [5/50] | LR: 0.001000 | Train Loss: 0.6071 | Val Loss: 0.5597
#   Saved best model at epoch 5 (Val Loss: 0.5597)
# Epoch [6/50] | LR: 0.001000 | Train Loss: 0.5970 | Val Loss: 0.5480
#   Saved best model at epoch 6 (Val Loss: 0.5480)
# Epoch [7/50] | LR: 0.001000 | Train Loss: 0.5608 | Val Loss: 0.5549
# Epoch [8/50] | LR: 0.001000 | Train Loss: 0.5303 | Val Loss: 0.4922
#   Saved best model at epoch 8 (Val Loss: 0.4922)
# Epoch [9/50] | LR: 0.001000 | Train Loss: 0.5052 | Val Loss: 0.4620
#   Saved best model at epoch 9 (Val Loss: 0.4620)
# Epoch [10/50] | LR: 0.001000 | Train Loss: 0.4826 | Val Loss: 0.4539
#   Saved best model at epoch 10 (Val Loss: 0.4539)
# Epoch [11/50] | LR: 0.001000 | Train Loss: 0.4635 | Val Loss: 0.5064
# Epoch [12/50] | LR: 0.001000 | Train Loss: 0.4559 | Val Loss: 0.4190
#   Saved best model at epoch 12 (Val Loss: 0.4190)
# Epoch [13/50] | LR: 0.001000 | Train Loss: 0.4313 | Val Loss: 0.4023
#   Saved best model at epoch 13 (Val Loss: 0.4023)
# Epoch [14/50] | LR: 0.001000 | Train Loss: 0.4220 | Val Loss: 0.4010
#   Saved best model at epoch 14 (Val Loss: 0.4010)
# Epoch [15/50] | LR: 0.001000 | Train Loss: 0.4118 | Val Loss: 0.3962
#   Saved best model at epoch 15 (Val Loss: 0.3962)
# Epoch [16/50] | LR: 0.001000 | Train Loss: 0.4005 | Val Loss: 0.3824
#   Saved best model at epoch 16 (Val Loss: 0.3824)
# Epoch [17/50] | LR: 0.001000 | Train Loss: 0.3876 | Val Loss: 0.3704
#   Saved best model at epoch 17 (Val Loss: 0.3704)
# Epoch [18/50] | LR: 0.001000 | Train Loss: 0.3781 | Val Loss: 0.3649
#   Saved best model at epoch 18 (Val Loss: 0.3649)
# Epoch [19/50] | LR: 0.001000 | Train Loss: 0.3797 | Val Loss: 0.3755
# Epoch [20/50] | LR: 0.001000 | Train Loss: 0.3718 | Val Loss: 0.3677
# Epoch [21/50] | LR: 0.001000 | Train Loss: 0.3628 | Val Loss: 0.3526
#   Saved best model at epoch 21 (Val Loss: 0.3526)
# Epoch [22/50] | LR: 0.001000 | Train Loss: 0.3564 | Val Loss: 0.3465
#   Saved best model at epoch 22 (Val Loss: 0.3465)
# Epoch [23/50] | LR: 0.001000 | Train Loss: 0.3518 | Val Loss: 0.3472
# Epoch [24/50] | LR: 0.001000 | Train Loss: 0.3451 | Val Loss: 0.3525
# Epoch [25/50] | LR: 0.001000 | Train Loss: 0.3402 | Val Loss: 0.3449
#   Saved best model at epoch 25 (Val Loss: 0.3449)
# Epoch [26/50] | LR: 0.001000 | Train Loss: 0.3373 | Val Loss: 0.3382
#   Saved best model at epoch 26 (Val Loss: 0.3382)
# Epoch [27/50] | LR: 0.001000 | Train Loss: 0.3333 | Val Loss: 0.3386
# Epoch [28/50] | LR: 0.001000 | Train Loss: 0.3272 | Val Loss: 0.3286
#   Saved best model at epoch 28 (Val Loss: 0.3286)
# Epoch [29/50] | LR: 0.001000 | Train Loss: 0.3186 | Val Loss: 0.3314
# Epoch [30/50] | LR: 0.001000 | Train Loss: 0.3174 | Val Loss: 0.3324
# Epoch [31/50] | LR: 0.001000 | Train Loss: 0.3260 | Val Loss: 0.3269
#   Saved best model at epoch 31 (Val Loss: 0.3269)
# Epoch [32/50] | LR: 0.001000 | Train Loss: 0.3063 | Val Loss: 0.3202
#   Saved best model at epoch 32 (Val Loss: 0.3202)
# Epoch [33/50] | LR: 0.001000 | Train Loss: 0.3086 | Val Loss: 0.3273
# Epoch [34/50] | LR: 0.001000 | Train Loss: 0.3065 | Val Loss: 0.3238
# Epoch [35/50] | LR: 0.001000 | Train Loss: 0.3004 | Val Loss: 0.3174
#   Saved best model at epoch 35 (Val Loss: 0.3174)
# Epoch [36/50] | LR: 0.001000 | Train Loss: 0.3058 | Val Loss: 0.3425
# Epoch [37/50] | LR: 0.001000 | Train Loss: 0.2972 | Val Loss: 0.3169
#   Saved best model at epoch 37 (Val Loss: 0.3169)
# Epoch [38/50] | LR: 0.001000 | Train Loss: 0.2993 | Val Loss: 0.3346
# Epoch [39/50] | LR: 0.001000 | Train Loss: 0.2935 | Val Loss: 0.3189
# Epoch [40/50] | LR: 0.001000 | Train Loss: 0.2917 | Val Loss: 0.3123
#   Saved best model at epoch 40 (Val Loss: 0.3123)
# Epoch [41/50] | LR: 0.001000 | Train Loss: 0.2830 | Val Loss: 0.3189
# Epoch [42/50] | LR: 0.001000 | Train Loss: 0.2865 | Val Loss: 0.3113
#   Saved best model at epoch 42 (Val Loss: 0.3113)
# Epoch [43/50] | LR: 0.001000 | Train Loss: 0.2768 | Val Loss: 0.3053
#   Saved best model at epoch 43 (Val Loss: 0.3053)
# Epoch [44/50] | LR: 0.001000 | Train Loss: 0.2774 | Val Loss: 0.3156
# Epoch [45/50] | LR: 0.001000 | Train Loss: 0.2819 | Val Loss: 0.3104
# Epoch [46/50] | LR: 0.001000 | Train Loss: 0.2718 | Val Loss: 0.3096
# Epoch [47/50] | LR: 0.001000 | Train Loss: 0.2730 | Val Loss: 0.3064
# Epoch [48/50] | LR: 0.001000 | Train Loss: 0.2657 | Val Loss: 0.3067
# Epoch [49/50] | LR: 0.001000 | Train Loss: 0.2612 | Val Loss: 0.3034
#   Saved best model at epoch 49 (Val Loss: 0.3034)
# Epoch [50/50] | LR: 0.001000 | Train Loss: 0.2609 | Val Loss: 0.3091
# './training_logs/fixed_dice_20250508_044052/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000961 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0224
# Precision      : 0.6472
# Recall         : 0.6199
# Fβ (β²=0.3): 0.6407
# Mean IoU       : 0.5210
# Obj Presence R : 0.9626
# Binarize thres.: 0.50
# Area fraction  : 0.000961
# === Evaluation Results ===
# MAE            : 0.0224
# Precision      : 0.6524
# Recall         : 0.6161
# Fβ (β²=0.3): 0.6436
# Mean IoU       : 0.5202
# Obj Presence R : 0.9627
# Binarize thres.: 0.30
# Area fraction  : 0.001000

# %%
# 4. Decaying LR, Dice
model = Saliency_RGB_v1().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5, verbose=True)
criterion = DiceLoss()
train_model(model, criterion, optimizer, scheduler, log_prefix="decay_dice")
# Out:
# Epoch [1/50] | LR: 0.001000 | Train Loss: 0.8135 | Val Loss: 0.6577
#   Saved best model at epoch 1 (Val Loss: 0.6577)
# Epoch [2/50] | LR: 0.001000 | Train Loss: 0.6612 | Val Loss: 0.6672
# Epoch [3/50] | LR: 0.001000 | Train Loss: 0.6373 | Val Loss: 0.5842
#   Saved best model at epoch 3 (Val Loss: 0.5842)
# Epoch [4/50] | LR: 0.001000 | Train Loss: 0.6105 | Val Loss: 0.5646
#   Saved best model at epoch 4 (Val Loss: 0.5646)
# Epoch [5/50] | LR: 0.001000 | Train Loss: 0.5834 | Val Loss: 0.5749
# Epoch [6/50] | LR: 0.001000 | Train Loss: 0.5979 | Val Loss: 0.5359
#   Saved best model at epoch 6 (Val Loss: 0.5359)
# Epoch [7/50] | LR: 0.001000 | Train Loss: 0.5519 | Val Loss: 0.5084
#   Saved best model at epoch 7 (Val Loss: 0.5084)
# Epoch [8/50] | LR: 0.001000 | Train Loss: 0.5306 | Val Loss: 0.4897
#   Saved best model at epoch 8 (Val Loss: 0.4897)
# Epoch [9/50] | LR: 0.001000 | Train Loss: 0.5167 | Val Loss: 0.4912
# Epoch [10/50] | LR: 0.001000 | Train Loss: 0.5004 | Val Loss: 0.4597
#   Saved best model at epoch 10 (Val Loss: 0.4597)
# Epoch [11/50] | LR: 0.001000 | Train Loss: 0.4761 | Val Loss: 0.4353
#   Saved best model at epoch 11 (Val Loss: 0.4353)
# Epoch [12/50] | LR: 0.001000 | Train Loss: 0.4657 | Val Loss: 0.4202
#   Saved best model at epoch 12 (Val Loss: 0.4202)
# Epoch [13/50] | LR: 0.001000 | Train Loss: 0.4467 | Val Loss: 0.4201
#   Saved best model at epoch 13 (Val Loss: 0.4201)
# Epoch [14/50] | LR: 0.001000 | Train Loss: 0.4330 | Val Loss: 0.4053
#   Saved best model at epoch 14 (Val Loss: 0.4053)
# Epoch [15/50] | LR: 0.001000 | Train Loss: 0.4180 | Val Loss: 0.3975
#   Saved best model at epoch 15 (Val Loss: 0.3975)
# Epoch [16/50] | LR: 0.001000 | Train Loss: 0.4153 | Val Loss: 0.4002
# Epoch [17/50] | LR: 0.001000 | Train Loss: 0.4030 | Val Loss: 0.4036
# Epoch [18/50] | LR: 0.001000 | Train Loss: 0.3999 | Val Loss: 0.3787
#   Saved best model at epoch 18 (Val Loss: 0.3787)
# Epoch [19/50] | LR: 0.001000 | Train Loss: 0.3926 | Val Loss: 0.3739
#   Saved best model at epoch 19 (Val Loss: 0.3739)
# Epoch [20/50] | LR: 0.001000 | Train Loss: 0.3820 | Val Loss: 0.3761
# Epoch [21/50] | LR: 0.001000 | Train Loss: 0.3753 | Val Loss: 0.3594
#   Saved best model at epoch 21 (Val Loss: 0.3594)
# Epoch [22/50] | LR: 0.001000 | Train Loss: 0.3858 | Val Loss: 0.3642
# Epoch [23/50] | LR: 0.001000 | Train Loss: 0.3651 | Val Loss: 0.3542
#   Saved best model at epoch 23 (Val Loss: 0.3542)
# Epoch [24/50] | LR: 0.001000 | Train Loss: 0.3542 | Val Loss: 0.3504
#   Saved best model at epoch 24 (Val Loss: 0.3504)
# Epoch [25/50] | LR: 0.001000 | Train Loss: 0.3498 | Val Loss: 0.3579
# Epoch [26/50] | LR: 0.001000 | Train Loss: 0.3475 | Val Loss: 0.3459
#   Saved best model at epoch 26 (Val Loss: 0.3459)
# Epoch [27/50] | LR: 0.001000 | Train Loss: 0.3519 | Val Loss: 0.3426
#   Saved best model at epoch 27 (Val Loss: 0.3426)
# Epoch [28/50] | LR: 0.001000 | Train Loss: 0.3421 | Val Loss: 0.3371
#   Saved best model at epoch 28 (Val Loss: 0.3371)
# Epoch [29/50] | LR: 0.001000 | Train Loss: 0.3314 | Val Loss: 0.3355
#   Saved best model at epoch 29 (Val Loss: 0.3355)
# Epoch [30/50] | LR: 0.001000 | Train Loss: 0.3369 | Val Loss: 0.3362
# Epoch [31/50] | LR: 0.001000 | Train Loss: 0.3353 | Val Loss: 0.3446
# Epoch [32/50] | LR: 0.001000 | Train Loss: 0.3268 | Val Loss: 0.3298
#   Saved best model at epoch 32 (Val Loss: 0.3298)
# Epoch [33/50] | LR: 0.001000 | Train Loss: 0.3312 | Val Loss: 0.3398
# Epoch [34/50] | LR: 0.001000 | Train Loss: 0.3154 | Val Loss: 0.3222
#   Saved best model at epoch 34 (Val Loss: 0.3222)
# Epoch [35/50] | LR: 0.001000 | Train Loss: 0.3167 | Val Loss: 0.3265
# Epoch [36/50] | LR: 0.001000 | Train Loss: 0.3133 | Val Loss: 0.3195
#   Saved best model at epoch 36 (Val Loss: 0.3195)
# Epoch [37/50] | LR: 0.001000 | Train Loss: 0.3077 | Val Loss: 0.3204
# Epoch [38/50] | LR: 0.001000 | Train Loss: 0.3012 | Val Loss: 0.3171
#   Saved best model at epoch 38 (Val Loss: 0.3171)
# Epoch [39/50] | LR: 0.001000 | Train Loss: 0.3021 | Val Loss: 0.3118
#   Saved best model at epoch 39 (Val Loss: 0.3118)
# Epoch [40/50] | LR: 0.001000 | Train Loss: 0.2997 | Val Loss: 0.3162
# Epoch [41/50] | LR: 0.001000 | Train Loss: 0.2994 | Val Loss: 0.3147
# Epoch [42/50] | LR: 0.001000 | Train Loss: 0.2973 | Val Loss: 0.3493
# Epoch [43/50] | LR: 0.001000 | Train Loss: 0.2969 | Val Loss: 0.3125
# Epoch [44/50] | LR: 0.001000 | Train Loss: 0.2849 | Val Loss: 0.3301
# Epoch [45/50] | LR: 0.001000 | Train Loss: 0.2893 | Val Loss: 0.3328
# Epoch [46/50] | LR: 0.000500 | Train Loss: 0.2770 | Val Loss: 0.2990
#   Saved best model at epoch 46 (Val Loss: 0.2990)
# Epoch [47/50] | LR: 0.000500 | Train Loss: 0.2671 | Val Loss: 0.3010
# Epoch [48/50] | LR: 0.000500 | Train Loss: 0.2656 | Val Loss: 0.3006
# Epoch [49/50] | LR: 0.000500 | Train Loss: 0.2655 | Val Loss: 0.2993
# Epoch [50/50] | LR: 0.000500 | Train Loss: 0.2601 | Val Loss: 0.3127
# './training_logs/decay_dice_20250508_055745/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000961 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0252
# Precision      : 0.6015
# Recall         : 0.6604
# Fβ (β²=0.3): 0.6141
# Mean IoU       : 0.4983
# Obj Presence R : 0.9780
# Binarize thres.: 0.50
# Area fraction  : 0.000961
# === Evaluation Results ===
# MAE            : 0.0252
# Precision      : 0.6052
# Recall         : 0.6568
# Fβ (β²=0.3): 0.6163
# Mean IoU       : 0.4970
# Obj Presence R : 0.9759
# Binarize thres.: 0.30
# Area fraction  : 0.001000

# %%
# 5. Fixed LR, Hybrid Loss (alpha=0.7)
model = Saliency_RGB_v1().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = HybridLoss(alpha=0.7)
train_model(model, criterion, optimizer, log_prefix="fixed_hybrid")
# Out:
# Epoch [1/50] | LR: 0.001000 | Train Loss: 0.4163 | Val Loss: 0.3834
#   Saved best model at epoch 1 (Val Loss: 0.3834)
# Epoch [2/50] | LR: 0.001000 | Train Loss: 0.3720 | Val Loss: 0.3557
#   Saved best model at epoch 2 (Val Loss: 0.3557)
# Epoch [3/50] | LR: 0.001000 | Train Loss: 0.3373 | Val Loss: 0.3215
#   Saved best model at epoch 3 (Val Loss: 0.3215)
# Epoch [4/50] | LR: 0.001000 | Train Loss: 0.3186 | Val Loss: 0.2957
#   Saved best model at epoch 4 (Val Loss: 0.2957)
# Epoch [5/50] | LR: 0.001000 | Train Loss: 0.2970 | Val Loss: 0.2690
#   Saved best model at epoch 5 (Val Loss: 0.2690)
# Epoch [6/50] | LR: 0.001000 | Train Loss: 0.2747 | Val Loss: 0.2713
# Epoch [7/50] | LR: 0.001000 | Train Loss: 0.2591 | Val Loss: 0.2424
#   Saved best model at epoch 7 (Val Loss: 0.2424)
# Epoch [8/50] | LR: 0.001000 | Train Loss: 0.2479 | Val Loss: 0.2349
#   Saved best model at epoch 8 (Val Loss: 0.2349)
# Epoch [9/50] | LR: 0.001000 | Train Loss: 0.2392 | Val Loss: 0.2321
#   Saved best model at epoch 9 (Val Loss: 0.2321)
# Epoch [10/50] | LR: 0.001000 | Train Loss: 0.2323 | Val Loss: 0.2094
#   Saved best model at epoch 10 (Val Loss: 0.2094)
# Epoch [11/50] | LR: 0.001000 | Train Loss: 0.2204 | Val Loss: 0.2029
#   Saved best model at epoch 11 (Val Loss: 0.2029)
# Epoch [12/50] | LR: 0.001000 | Train Loss: 0.2168 | Val Loss: 0.1983
#   Saved best model at epoch 12 (Val Loss: 0.1983)
# Epoch [13/50] | LR: 0.001000 | Train Loss: 0.2084 | Val Loss: 0.2045
# Epoch [14/50] | LR: 0.001000 | Train Loss: 0.2040 | Val Loss: 0.1875
#   Saved best model at epoch 14 (Val Loss: 0.1875)
# Epoch [15/50] | LR: 0.001000 | Train Loss: 0.1970 | Val Loss: 0.1870
#   Saved best model at epoch 15 (Val Loss: 0.1870)
# Epoch [16/50] | LR: 0.001000 | Train Loss: 0.1908 | Val Loss: 0.1798
#   Saved best model at epoch 16 (Val Loss: 0.1798)
# Epoch [17/50] | LR: 0.001000 | Train Loss: 0.1896 | Val Loss: 0.1778
#   Saved best model at epoch 17 (Val Loss: 0.1778)
# Epoch [18/50] | LR: 0.001000 | Train Loss: 0.1848 | Val Loss: 0.1775
#   Saved best model at epoch 18 (Val Loss: 0.1775)
# Epoch [19/50] | LR: 0.001000 | Train Loss: 0.1820 | Val Loss: 0.1752
#   Saved best model at epoch 19 (Val Loss: 0.1752)
# Epoch [20/50] | LR: 0.001000 | Train Loss: 0.1762 | Val Loss: 0.1706
#   Saved best model at epoch 20 (Val Loss: 0.1706)
# Epoch [21/50] | LR: 0.001000 | Train Loss: 0.1756 | Val Loss: 0.1734
# Epoch [22/50] | LR: 0.001000 | Train Loss: 0.1711 | Val Loss: 0.1716
# Epoch [23/50] | LR: 0.001000 | Train Loss: 0.1711 | Val Loss: 0.1626
#   Saved best model at epoch 23 (Val Loss: 0.1626)
# Epoch [24/50] | LR: 0.001000 | Train Loss: 0.1638 | Val Loss: 0.1603
#   Saved best model at epoch 24 (Val Loss: 0.1603)
# Epoch [25/50] | LR: 0.001000 | Train Loss: 0.1623 | Val Loss: 0.1624
# Epoch [26/50] | LR: 0.001000 | Train Loss: 0.1598 | Val Loss: 0.1643
# Epoch [27/50] | LR: 0.001000 | Train Loss: 0.1590 | Val Loss: 0.1625
# Epoch [28/50] | LR: 0.001000 | Train Loss: 0.1629 | Val Loss: 0.1609
# Epoch [29/50] | LR: 0.001000 | Train Loss: 0.1521 | Val Loss: 0.1629
# Epoch [30/50] | LR: 0.001000 | Train Loss: 0.1507 | Val Loss: 0.1647
# Epoch [31/50] | LR: 0.001000 | Train Loss: 0.1499 | Val Loss: 0.1644
# Epoch [32/50] | LR: 0.001000 | Train Loss: 0.1476 | Val Loss: 0.1527
#   Saved best model at epoch 32 (Val Loss: 0.1527)
# Epoch [33/50] | LR: 0.001000 | Train Loss: 0.1480 | Val Loss: 0.1535
# Epoch [34/50] | LR: 0.001000 | Train Loss: 0.1441 | Val Loss: 0.1593
# Epoch [35/50] | LR: 0.001000 | Train Loss: 0.1458 | Val Loss: 0.1527
#   Saved best model at epoch 35 (Val Loss: 0.1527)
# Epoch [36/50] | LR: 0.001000 | Train Loss: 0.1402 | Val Loss: 0.1580
# Epoch [37/50] | LR: 0.001000 | Train Loss: 0.1379 | Val Loss: 0.1543
# Epoch [38/50] | LR: 0.001000 | Train Loss: 0.1367 | Val Loss: 0.1592
# Epoch [39/50] | LR: 0.001000 | Train Loss: 0.1371 | Val Loss: 0.1623
# Epoch [40/50] | LR: 0.001000 | Train Loss: 0.1360 | Val Loss: 0.1534
# Epoch [41/50] | LR: 0.001000 | Train Loss: 0.1341 | Val Loss: 0.1567
# Epoch [42/50] | LR: 0.001000 | Train Loss: 0.1345 | Val Loss: 0.1489
#   Saved best model at epoch 42 (Val Loss: 0.1489)
# Epoch [43/50] | LR: 0.001000 | Train Loss: 0.1282 | Val Loss: 0.1469
#   Saved best model at epoch 43 (Val Loss: 0.1469)
# Epoch [44/50] | LR: 0.001000 | Train Loss: 0.1272 | Val Loss: 0.1492
# Epoch [45/50] | LR: 0.001000 | Train Loss: 0.1268 | Val Loss: 0.1582
# Epoch [46/50] | LR: 0.001000 | Train Loss: 0.1279 | Val Loss: 0.1499
# Epoch [47/50] | LR: 0.001000 | Train Loss: 0.1232 | Val Loss: 0.1515
# Epoch [48/50] | LR: 0.001000 | Train Loss: 0.1243 | Val Loss: 0.1511
# Epoch [49/50] | LR: 0.001000 | Train Loss: 0.1257 | Val Loss: 0.1471
# Epoch [50/50] | LR: 0.001000 | Train Loss: 0.1205 | Val Loss: 0.1491
# './training_logs/fixed_hybrid_20250508_071512/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000961 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0249
# Precision      : 0.6674
# Recall         : 0.6331
# Fβ (β²=0.3): 0.6592
# Mean IoU       : 0.5474
# Obj Presence R : 0.9692
# Binarize thres.: 0.50
# Area fraction  : 0.000961
# === Evaluation Results ===
# MAE            : 0.0249
# Precision      : 0.6436
# Recall         : 0.6501
# Fβ (β²=0.3): 0.6451
# Mean IoU       : 0.5285
# Obj Presence R : 0.9781
# Binarize thres.: 0.30
# Area fraction  : 0.001000

# %%
# 6. Decaying LR, Hybrid Loss (alpha=0.7)
model = Saliency_RGB_v1().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5, verbose=True)
criterion = HybridLoss(alpha=0.7)
train_model(model, criterion, optimizer, scheduler, log_prefix="decay_hybrid")
# Out:
# Epoch [1/50] | LR: 0.001000 | Train Loss: 0.4313 | Val Loss: 0.3874
#   Saved best model at epoch 1 (Val Loss: 0.3874)
# Epoch [2/50] | LR: 0.001000 | Train Loss: 0.3786 | Val Loss: 0.3614
#   Saved best model at epoch 2 (Val Loss: 0.3614)
# Epoch [3/50] | LR: 0.001000 | Train Loss: 0.3559 | Val Loss: 0.3501
#   Saved best model at epoch 3 (Val Loss: 0.3501)
# Epoch [4/50] | LR: 0.001000 | Train Loss: 0.3363 | Val Loss: 0.3277
#   Saved best model at epoch 4 (Val Loss: 0.3277)
# Epoch [5/50] | LR: 0.001000 | Train Loss: 0.3184 | Val Loss: 0.2936
#   Saved best model at epoch 5 (Val Loss: 0.2936)
# Epoch [6/50] | LR: 0.001000 | Train Loss: 0.2996 | Val Loss: 0.2920
#   Saved best model at epoch 6 (Val Loss: 0.2920)
# Epoch [7/50] | LR: 0.001000 | Train Loss: 0.2815 | Val Loss: 0.2747
#   Saved best model at epoch 7 (Val Loss: 0.2747)
# Epoch [8/50] | LR: 0.001000 | Train Loss: 0.2668 | Val Loss: 0.2488
#   Saved best model at epoch 8 (Val Loss: 0.2488)
# Epoch [9/50] | LR: 0.001000 | Train Loss: 0.2550 | Val Loss: 0.2317
#   Saved best model at epoch 9 (Val Loss: 0.2317)
# Epoch [10/50] | LR: 0.001000 | Train Loss: 0.2473 | Val Loss: 0.2202
#   Saved best model at epoch 10 (Val Loss: 0.2202)
# Epoch [11/50] | LR: 0.001000 | Train Loss: 0.2355 | Val Loss: 0.2254
# Epoch [12/50] | LR: 0.001000 | Train Loss: 0.2300 | Val Loss: 0.2144
#   Saved best model at epoch 12 (Val Loss: 0.2144)
# Epoch [13/50] | LR: 0.001000 | Train Loss: 0.2185 | Val Loss: 0.2135
#   Saved best model at epoch 13 (Val Loss: 0.2135)
# Epoch [14/50] | LR: 0.001000 | Train Loss: 0.2169 | Val Loss: 0.1973
#   Saved best model at epoch 14 (Val Loss: 0.1973)
# Epoch [15/50] | LR: 0.001000 | Train Loss: 0.2065 | Val Loss: 0.1965
#   Saved best model at epoch 15 (Val Loss: 0.1965)
# Epoch [16/50] | LR: 0.001000 | Train Loss: 0.2012 | Val Loss: 0.1887
#   Saved best model at epoch 16 (Val Loss: 0.1887)
# Epoch [17/50] | LR: 0.001000 | Train Loss: 0.1988 | Val Loss: 0.1851
#   Saved best model at epoch 17 (Val Loss: 0.1851)
# Epoch [18/50] | LR: 0.001000 | Train Loss: 0.1918 | Val Loss: 0.1823
#   Saved best model at epoch 18 (Val Loss: 0.1823)
# Epoch [19/50] | LR: 0.001000 | Train Loss: 0.1905 | Val Loss: 0.1792
#   Saved best model at epoch 19 (Val Loss: 0.1792)
# Epoch [20/50] | LR: 0.001000 | Train Loss: 0.1852 | Val Loss: 0.1708
#   Saved best model at epoch 20 (Val Loss: 0.1708)
# Epoch [21/50] | LR: 0.001000 | Train Loss: 0.1784 | Val Loss: 0.1762
# Epoch [22/50] | LR: 0.001000 | Train Loss: 0.1757 | Val Loss: 0.1697
#   Saved best model at epoch 22 (Val Loss: 0.1697)
# Epoch [23/50] | LR: 0.001000 | Train Loss: 0.1782 | Val Loss: 0.1670
#   Saved best model at epoch 23 (Val Loss: 0.1670)
# Epoch [24/50] | LR: 0.001000 | Train Loss: 0.1719 | Val Loss: 0.1643
#   Saved best model at epoch 24 (Val Loss: 0.1643)
# Epoch [25/50] | LR: 0.001000 | Train Loss: 0.1674 | Val Loss: 0.1679
# Epoch [26/50] | LR: 0.001000 | Train Loss: 0.1684 | Val Loss: 0.1615
#   Saved best model at epoch 26 (Val Loss: 0.1615)
# Epoch [27/50] | LR: 0.001000 | Train Loss: 0.1628 | Val Loss: 0.1614
#   Saved best model at epoch 27 (Val Loss: 0.1614)
# Epoch [28/50] | LR: 0.001000 | Train Loss: 0.1627 | Val Loss: 0.1585
#   Saved best model at epoch 28 (Val Loss: 0.1585)
# Epoch [29/50] | LR: 0.001000 | Train Loss: 0.1595 | Val Loss: 0.1582
#   Saved best model at epoch 29 (Val Loss: 0.1582)
# Epoch [30/50] | LR: 0.001000 | Train Loss: 0.1580 | Val Loss: 0.1623
# Epoch [31/50] | LR: 0.001000 | Train Loss: 0.1537 | Val Loss: 0.1545
#   Saved best model at epoch 31 (Val Loss: 0.1545)
# Epoch [32/50] | LR: 0.001000 | Train Loss: 0.1536 | Val Loss: 0.1559
# Epoch [33/50] | LR: 0.001000 | Train Loss: 0.1516 | Val Loss: 0.1690
# Epoch [34/50] | LR: 0.001000 | Train Loss: 0.1488 | Val Loss: 0.1550
# Epoch [35/50] | LR: 0.001000 | Train Loss: 0.1459 | Val Loss: 0.1734
# Epoch [36/50] | LR: 0.001000 | Train Loss: 0.1457 | Val Loss: 0.1513
#   Saved best model at epoch 36 (Val Loss: 0.1513)
# Epoch [37/50] | LR: 0.001000 | Train Loss: 0.1477 | Val Loss: 0.1553
# Epoch [38/50] | LR: 0.001000 | Train Loss: 0.1426 | Val Loss: 0.1611
# Epoch [39/50] | LR: 0.001000 | Train Loss: 0.1396 | Val Loss: 0.1549
# Epoch [40/50] | LR: 0.001000 | Train Loss: 0.1401 | Val Loss: 0.1529
# Epoch [41/50] | LR: 0.001000 | Train Loss: 0.1369 | Val Loss: 0.1481
#   Saved best model at epoch 41 (Val Loss: 0.1481)
# Epoch [42/50] | LR: 0.001000 | Train Loss: 0.1336 | Val Loss: 0.1466
#   Saved best model at epoch 42 (Val Loss: 0.1466)
# Epoch [43/50] | LR: 0.001000 | Train Loss: 0.1306 | Val Loss: 0.1519
# Epoch [44/50] | LR: 0.001000 | Train Loss: 0.1330 | Val Loss: 0.1465
#   Saved best model at epoch 44 (Val Loss: 0.1465)
# Epoch [45/50] | LR: 0.001000 | Train Loss: 0.1306 | Val Loss: 0.1525
# Epoch [46/50] | LR: 0.001000 | Train Loss: 0.1285 | Val Loss: 0.1468
# Epoch [47/50] | LR: 0.001000 | Train Loss: 0.1271 | Val Loss: 0.1460
#   Saved best model at epoch 47 (Val Loss: 0.1460)
# Epoch [48/50] | LR: 0.001000 | Train Loss: 0.1264 | Val Loss: 0.1472
# Epoch [49/50] | LR: 0.001000 | Train Loss: 0.1237 | Val Loss: 0.1437
#   Saved best model at epoch 49 (Val Loss: 0.1437)
# Epoch [50/50] | LR: 0.001000 | Train Loss: 0.1245 | Val Loss: 0.1470
# './training_logs/decay_hybrid_20250508_083226/best_model.pth'

# %%
# 1) Default 0.5 bin_thresh, compute area_frac from GT masks:
metrics = evaluate_model(
    model, test_loader, device,
    compute_area_frac=True,
    visualize=True
)

# 2) Fixed area_frac=0.001, custom bin_thresh=0.6:
metrics = evaluate_model(
    model, test_loader, device,
    bin_thresh=0.3,
    area_frac=0.001,
    compute_area_frac=False
)
# Out:
# [INFO] Computed area_frac=0.000961 from GT masks
#
# === Evaluation Results ===
# MAE            : 0.0241
# Precision      : 0.6855
# Recall         : 0.6366
# Fβ (β²=0.3): 0.6735
# Mean IoU       : 0.5724
# Obj Presence R : 0.9802
# Binarize thres.: 0.50
# Area fraction  : 0.000961
# === Evaluation Results ===
# MAE            : 0.0241
# Precision      : 0.6664
# Recall         : 0.6549
# Fβ (β²=0.3): 0.6637
# Mean IoU       : 0.5678
# Obj Presence R : 0.9781
# Binarize thres.: 0.30
# Area fraction  : 0.001000

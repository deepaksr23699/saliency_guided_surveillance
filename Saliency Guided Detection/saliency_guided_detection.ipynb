# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# Setup complete ✅ (32 CPUs, 125.6 GB RAM, 1076.3/1832.2 GB disk)

# %% [markdown]
# ## Simulated Dataset

# %% [markdown]
# ### Result of fusing input images with saliency mask only for inference

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d1/train_n/weights/best.pt')

# Evaluate on fused images using fused dataset YAML
metrics = model.val(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/simulated/dataset.yaml",  # path to fused dataset YAML
    split='test',
    name='test_fused',  # optional name for run folder
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d1"
)

# Print evaluation metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/simulated/labels/test... 414 images, 31 backgrounds, 0 corrupt: 100%|██████████| 414/414 [00:00<00:00, 1529.33it/s]
# val: New cache created: /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/simulated/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:00<00:00, 32.36it/s]
#                    all        414        396      0.976      0.984      0.991      0.623
#                 Person        181        194      0.976       0.99       0.99      0.572
#                    Car        202        202      0.975      0.979      0.993      0.674
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on coco) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('yolo11n.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/simulated/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_n',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d1",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d1/train_n/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_n',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d1"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/simulated/labels/test.cache... 414 images, 31 backgrounds, 0 corrupt: 100%|██████████| 414/414 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:00<00:00, 32.64it/s]
#                    all        414        396      0.977      0.986      0.993      0.783
#                 Person        181        194      0.975      0.986      0.991      0.714
#                    Car        202        202       0.98      0.986      0.995      0.852
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d1/test_n
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on raw dataset) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d1/train_n/weights/best.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/simulated/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_pre_d1',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d1",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d1/train_pre_d1/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_pre_d1',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d1"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/simulated/labels/test.cache... 414 images, 31 backgrounds, 0 corrupt: 100%|██████████| 414/414 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:00<00:00, 36.96it/s]
#                    all        414        396      0.992      0.996      0.995      0.797
#                 Person        181        194      0.988          1      0.995      0.733
#                    Car        202        202      0.995      0.991      0.995      0.861
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d1/test_pre_d1
# ...

# %% [markdown]
# ## Paper Dataset

# %% [markdown]
# ### Result of fusing input images with saliency mask only for inference

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d2/train_n/weights/best.pt')

# Evaluate on fused images using fused dataset YAML
metrics = model.val(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/paper/dataset.yaml",  # path to fused dataset YAML
    split='test',
    name='test_fused',  # optional name for run folder
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d2"
)

# Print evaluation metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/paper/labels/test... 315 images, 0 backgrounds, 0 corrupt: 100%|██████████| 315/315 [00:00<00:00, 1324.76it/s]
# val: New cache created: /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/paper/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:01<00:00, 16.74it/s]
#                    all        315       1865      0.788      0.777      0.845      0.567
#                  Truck        140        155      0.858      0.877      0.929      0.701
#                    Car        222       1462      0.805      0.775      0.857      0.602
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on coco) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('yolo11n.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/paper/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_n',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d2",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d2/train_n/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_n',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d2"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/paper/labels/test.cache... 315 images, 0 backgrounds, 0 corrupt: 100%|██████████| 315/315 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:01<00:00, 19.85it/s]
#                    all        315       1865      0.791      0.804      0.859       0.59
#                  Truck        140        155      0.888      0.865      0.931       0.72
#                    Car        222       1462      0.784      0.829      0.876      0.625
#                 Person        100        248      0.701      0.718      0.769      0.424
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.9ms postprocess per image
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on raw dataset) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d2/train_n/weights/best.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/paper/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_pre_d2',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d2",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d2/train_pre_d2/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_pre_d2',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d2"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/paper/labels/test.cache... 315 images, 0 backgrounds, 0 corrupt: 100%|██████████| 315/315 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:00<00:00, 22.12it/s]
#                    all        315       1865       0.83      0.794      0.874        0.6
#                  Truck        140        155      0.924      0.903      0.962      0.739
#                    Car        222       1462      0.819        0.8      0.882      0.635
#                 Person        100        248      0.747      0.678      0.779      0.426
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 1.0ms postprocess per image
# ...

# %% [markdown]
# ## IR Military Dataset

# %% [markdown]
# ### Result of fusing input images with saliency mask only for inference

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d3/train_n/weights/best.pt')

# Evaluate on fused images using fused dataset YAML
metrics = model.val(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/actual_ir/dataset.yaml",  # path to fused dataset YAML
    split='test',
    name='test_fused',  # optional name for run folder
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d3"
)

# Print evaluation metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/actual_ir/labels/test... 3297 images, 267 backgrounds, 0 corrupt: 100%|██████████| 3297/3297 [00:04<00:00, 719.44it/s]
# val: New cache created: /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/actual_ir/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 207/207 [00:05<00:00, 40.25it/s]
#                    all       3297      10054      0.954      0.919      0.963      0.654
#                 Person       2596       7283       0.89       0.86      0.929      0.541
#                    JCB        950        950      0.995      0.997      0.995      0.814
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on coco) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('yolo11n.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/actual_ir/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_n',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d3",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d3/train_n/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_n',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d3"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/actual_ir/labels/test.cache... 3297 images, 267 backgrounds, 0 corrupt: 100%|██████████| 3297/3297 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 207/207 [00:05<00:00, 39.99it/s]
#                    all       3297      10054      0.991      0.991      0.993       0.85
#                 Person       2596       7283      0.972      0.974       0.99      0.727
#                    JCB        950        950          1          1      0.995      0.871
#                Vehicle       1032       1821          1      0.999      0.995      0.952
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.2ms postprocess per image
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on raw dataset) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d3/train_n/weights/best.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/actual_ir/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_pre_d3',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d3",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d3/train_pre_d3/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_pre_d3', 
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d3"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/actual_ir/labels/test.cache... 3297 images, 267 backgrounds, 0 corrupt: 100%|██████████| 3297/3297 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 207/207 [00:05<00:00, 39.96it/s]
#                    all       3297      10054      0.992      0.992      0.994       0.88
#                 Person       2596       7283      0.977      0.977      0.992      0.769
#                    JCB        950        950          1          1      0.995      0.899
#                Vehicle       1032       1821          1      0.999      0.995      0.971
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.2ms postprocess per image
# ...

# %% [markdown]
# ## IR Vehicle Dataset

# %% [markdown]
# ### Result of fusing input images with saliency mask only for inference

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d4/train_n/weights/best.pt')

# Evaluate on fused images using fused dataset YAML
metrics = model.val(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/vehicle_ir/dataset.yaml",  # path to fused dataset YAML
    split='test',
    name='test_fused',  # optional name for run folder
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d4"
)

# Print evaluation metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/vehicle_ir/labels/test... 283 images, 0 backgrounds, 0 corrupt: 100%|██████████| 283/283 [00:00<00:00, 996.33it/s]
# val: New cache created: /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/vehicle_ir/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:00<00:00, 21.50it/s]
#                    all        283       1264       0.82      0.846      0.881      0.483
#                Vehicle        181        288      0.791      0.861      0.914      0.511
#                    Car        271        633      0.894      0.885       0.94      0.567
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on coco) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('yolo11n.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/vehicle_ir/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_n',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d4",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d4/train_n/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_n',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d4"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/vehicle_ir/labels/test.cache... 283 images, 0 backgrounds, 0 corrupt: 100%|██████████| 283/283 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:00<00:00, 23.32it/s]
#                    all        283       1264       0.92      0.891      0.952      0.608
#                Vehicle        181        288      0.936      0.882      0.964      0.654
#                    Car        271        633      0.934      0.939      0.977      0.691
#            Two Wheeler        211        343       0.89      0.853      0.916      0.479
# Speed: 0.1ms preprocess, 0.9ms inference, 0.0ms loss, 0.3ms postprocess per image
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on raw dataset) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d4/train_n/weights/best.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/vehicle_ir/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_pre_d4',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d4",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d4/train_pre_d4/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_pre_d4', 
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d4"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/vehicle_ir/labels/test.cache... 283 images, 0 backgrounds, 0 corrupt: 100%|██████████| 283/283 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:00<00:00, 23.47it/s]
#                    all        283       1264      0.903      0.912      0.958      0.644
#                Vehicle        181        288      0.908      0.928      0.973      0.699
#                    Car        271        633      0.919      0.954      0.981      0.723
#            Two Wheeler        211        343      0.881      0.854      0.918      0.512
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.5ms postprocess per image
# ...

# %% [markdown]
# ## Hit-Uav Dataset

# %% [markdown]
# ### Result of fusing input images with saliency mask only for inference

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d5/train_n/weights/best.pt')

# Evaluate on fused images using fused dataset YAML
metrics = model.val(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/hit-uav/dataset.yaml",  # path to fused dataset YAML
    split='test',
    name='test_fused',  # optional name for run folder
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d5"
)

# Print evaluation metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/hit-uav/labels/test... 571 images, 0 backgrounds, 0 corrupt: 100%|██████████| 571/571 [00:00<00:00, 1667.81it/s]
# val: New cache created: /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/hit-uav/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 36/36 [00:01<00:00, 21.86it/s]
#                    all        571       4811      0.787      0.622      0.704      0.425
#                 Person        355       2611       0.85       0.82      0.867      0.421
#                    Car        267       1339      0.882      0.903      0.949      0.661
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on coco) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('yolo11n.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/hit-uav/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_n',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d5",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d5/train_n/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_n',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d5"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/hit-uav/labels/test.cache... 571 images, 0 backgrounds, 0 corrupt: 100%|██████████| 571/571 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 36/36 [00:01<00:00, 24.48it/s]
#                    all        571       4811      0.747      0.657      0.711       0.45
#                 Person        355       2611      0.837      0.853      0.895      0.465
#                    Car        267       1339      0.848      0.957      0.967      0.685
#                Bicycle         86        796      0.782      0.796      0.866      0.528
#           OtherVehicle         21         34      0.588      0.294      0.419      0.308
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on raw dataset) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d5/train_n/weights/best.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/hit-uav/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_pre_d5',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d5",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d5/train_pre_d5/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_pre_d5', 
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d5"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/hit-uav/labels/test.cache... 571 images, 0 backgrounds, 0 corrupt: 100%|██████████| 571/571 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 36/36 [00:01<00:00, 22.55it/s]
#                    all        571       4811      0.765      0.769      0.803      0.519
#                 Person        355       2611      0.851      0.886      0.915       0.49
#                    Car        267       1339      0.889      0.957      0.973      0.727
#                Bicycle         86        796      0.798      0.867      0.902      0.559
#           OtherVehicle         21         34       0.65      0.618      0.682      0.488
# ...

# %% [markdown]
# ## Combined Dataset

# %% [markdown]
# ### Result of fusing input images with saliency mask only for inference

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d6/train_n/weights/best.pt')

# Evaluate on fused images using fused dataset YAML
metrics = model.val(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/combined/data.yaml",  # path to fused dataset YAML
    split='test',
    name='test_fused',  # optional name for run folder
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d6"
)

# Print evaluation metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/combined/labels/test... 3157 images, 194 backgrounds, 0 corrupt: 100%|██████████| 3157/3157 [00:03<00:00, 814.92it/s]
# val: New cache created: /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/combined/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 198/198 [00:05<00:00, 36.83it/s]
#                    all       3157      11975      0.863      0.823      0.872      0.552
#                 Person       2123       6587      0.892      0.862      0.927       0.54
#                    Car        572       2335      0.827      0.819      0.899      0.581
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on coco) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('yolo11n.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/combined/data.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_n',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d6",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d6/train_n/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_n',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d6"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/combined/labels/test.cache... 3157 images, 194 backgrounds, 0 corrupt: 100%|██████████| 3157/3157 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 198/198 [00:05<00:00, 37.00it/s]
#                    all       3157      11975      0.925      0.871      0.907      0.657
#                 Person       2123       6587      0.924       0.93      0.967      0.653
#                    Car        572       2335      0.837      0.866      0.926      0.666
#          Vehicle_Other        966       1618      0.972      0.965      0.991       0.89
#                    JCB        683        683      0.999          1      0.995      0.864
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on raw dataset) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_d6/train_n/weights/best.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/combined/data.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_pre_d6',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d6",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d6/train_pre_d6/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_pre_d6', 
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_ir_salfused_d6"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/IR_saliencyfused/combined/labels/test.cache... 3157 images, 194 backgrounds, 0 corrupt: 100%|██████████| 3157/3157 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 198/198 [00:05<00:00, 37.16it/s]
#                    all       3157      11975      0.926      0.872      0.922      0.692
#                 Person       2123       6587       0.95      0.931      0.976      0.685
#                    Car        572       2335      0.875      0.863       0.94      0.684
#          Vehicle_Other        966       1618      0.981      0.967      0.993      0.921
#                    JCB        683        683      0.999          1      0.995      0.893
# ...

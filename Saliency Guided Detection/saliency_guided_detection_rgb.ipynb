# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# Setup complete ✅ (32 CPUs, 125.6 GB RAM, 1082.0/1832.2 GB disk)

# %% [markdown]
# ## Simulated Dataset

# %% [markdown]
# ### Result of fusing input images with saliency mask only for inference

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_d1/train_n/weights/best.pt')

# Evaluate on fused images using fused dataset YAML
metrics = model.val(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/simulated/dataset.yaml",  # path to fused dataset YAML
    split='test',
    name='test_fused',  # optional name for run folder
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_d1"
)

# Print evaluation metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/simulated/labels/test... 414 images, 38 backgrounds, 0 corrupt: 100%|██████████| 414/414 [00:00<00:00, 1401.04it/s]
# val: New cache created: /home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/simulated/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:00<00:00, 33.52it/s]
#                    all        414        383      0.967      0.978      0.992      0.805
#                 Person        203        210      0.982      0.967      0.992      0.756
#                    Car        173        173      0.953      0.988      0.992      0.854
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on coco) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('yolo11n.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/simulated/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_n',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d1",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d1/train_n/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_n',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d1"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/simulated/labels/test.cache... 414 images, 38 backgrounds, 0 corrupt: 100%|██████████| 414/414 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:00<00:00, 33.61it/s]
#                    all        414        383      0.994      0.997      0.995      0.858
#                 Person        203        210          1          1      0.995      0.811
#                    Car        173        173      0.988      0.994      0.994      0.905
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d1/test_n
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on raw dataset) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_d1/train_n/weights/best.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/simulated/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_pre_d1',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d1",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d1/train_pre_d1/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_pre_d1',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d1"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/simulated/labels/test.cache... 414 images, 38 backgrounds, 0 corrupt: 100%|██████████| 414/414 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:00<00:00, 37.13it/s]
#                    all        414        383      0.994      0.991      0.993      0.871
#                 Person        203        210      0.999      0.995      0.995      0.831
#                    Car        173        173      0.988      0.988       0.99      0.912
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d1/test_pre_d1
# ...

# %% [markdown]
# ## Paper Dataset

# %% [markdown]
# ### Result of fusing input images with saliency mask only for inference

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_d2/train_n/weights/best.pt')

# Evaluate on fused images using fused dataset YAML
metrics = model.val(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/paper/dataset.yaml",  # path to fused dataset YAML
    split='test',
    name='test_fused',  # optional name for run folder
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_d2"
)

# Print evaluation metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/paper/labels/test... 315 images, 0 backgrounds, 0 corrupt: 100%|██████████| 315/315 [00:00<00:00, 1338.96it/s]
# val: New cache created: /home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/paper/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:01<00:00, 14.73it/s]
#                    all        315       2724       0.68      0.689      0.739      0.477
#                  Truck        193        229       0.72      0.777      0.829      0.585
#                    Car        242       2094      0.719      0.819       0.85      0.599
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on coco) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('yolo11n.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/paper/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_n',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d2",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d2/train_n/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_n',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d2"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/paper/labels/test.cache... 315 images, 0 backgrounds, 0 corrupt: 100%|██████████| 315/315 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:01<00:00, 17.71it/s]
#                    all        315       2724      0.797      0.778      0.853      0.572
#                  Truck        193        229       0.86      0.865      0.921      0.689
#                    Car        242       2094       0.78      0.851      0.897      0.673
#                 Person        116        401      0.751      0.618       0.74      0.354
# Speed: 0.1ms preprocess, 0.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %% [markdown]
# ### Result of fusing input images with saliency mask for training(Pretrained on raw dataset) and eval

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model (nano version)
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_d2/train_n/weights/best.pt')

# Train the model
results = model.train(
    data="/home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/paper/dataset.yaml",  
    epochs=20,
    imgsz=640,
    batch=32,
    name='train_pre_d2',  
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d2",
    workers=4,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# ...

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO('/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d2/train_pre_d2/weights/best.pt')

# Evaluate on test set
metrics = model.val(
    split='test',
    name='test_pre_d2',  #  separate subfolder for test
    project="/home/samy/shivam/dsr_project/Project_files/runs/yolov11_rgb_salfused_d2"
)

# Print test metrics
print(metrics)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090, 24085MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/samy/shivam/dsr_project/salguided_od_datasets/RGB_saliencyfused/paper/labels/test.cache... 315 images, 0 backgrounds, 0 corrupt: 100%|██████████| 315/315 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:01<00:00, 15.62it/s]
#                    all        315       2724      0.806      0.827      0.877      0.598
#                  Truck        193        229      0.897      0.917      0.953      0.735
#                    Car        242       2094      0.778      0.879      0.906      0.684
#                 Person        116        401      0.743      0.683      0.771      0.374
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 1.9ms postprocess per image
# ...
